# %%
import psycopg2
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /usr/local/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
conn = psycopg2.connect("dbname=football")
cur = conn.cursor()

sql = """
WITH markets AS (
    SELECT
        event_name,
        event_id,
        open_date,
        mc_id
    FROM
        market_changes
    GROUP BY
        event_name,
        event_id,
        open_date,
        mc_id
)

SELECT
mc.event_name,
mc.event_id,
mc.open_date,
min(r.name) AS score_name
FROM
runners r
INNER JOIN
markets mc
ON mc.mc_id = r.mc_id
WHERE r.status = 'WINNER'
GROUP BY
mc.event_name,
mc.event_id,
mc.open_date
ORDER BY
mc.event_id
"""

cur.execute(sql)

results = cur.fetchall()
colnames = [desc[0] for desc in cur.description]
conn.close()

# %%
df = pd.DataFrame(results, columns=colnames)
df.head()
# Out:
#              event_name  event_id           open_date score_name
# 0                 T v A  27041861 2013-07-29 10:14:25      0 - 0
# 1           New v Cat 5  27041907 2013-07-29 11:44:42      1 - 0
# 2        Test v Subject  27144881 2015-12-14 12:34:00      1 - 0
# 3        Test v Subject  27144881 2020-02-06 11:30:00      1 - 0
# 4  Tottenham v Man City  27425811 2015-05-03 15:00:00      0 - 1

# %%
df.shape
# Out:
# (25036, 4)

# %% [markdown]
# ### Creating results

# %%
df.loc[:, 'home_team'] = df.event_name.apply(lambda x: x.split(' v ')[0])
df.loc[:, 'away_team'] = df.event_name.apply(lambda x: x.split(' v ')[-1])
df = df[(df.open_date >= '2015-04-01') & (df.open_date < '2019-01-01')].sort_values(by='open_date')
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team
# 6                1 - 3               Leicester            Chelsea
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic
# 17               5 - 0                  Celtic             Dundee
# 59               1 - 2            Nottm Forest            Cardiff
# 58               4 - 2                 Norwich             Fulham

# %% [markdown]
# ## ELO

# %%
HISTORY = 10
k_factor = 32
elo_width = 400.

def calculate_new_elos(rating_a, rating_b, score_a, k_factor, elo_width):
    """Calculates and returns the new Elo ratings for two players.
    score_a is 1 for a win by player A, 0 for a loss by player A, or 0.5 for a draw.
    """

    e_a = expected_result(rating_a, rating_b, elo_width)
    e_b = 1. - e_a
    new_rating_a = rating_a + k_factor * (score_a - e_a)
    score_b = 1. - score_a
    new_rating_b = rating_b + k_factor * (score_b - e_b)
    return new_rating_a, new_rating_b
    

def expected_result(elo_a, elo_b, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expect_a = 1.0/(1+10**((elo_b - elo_a)/elo_width))
    return expect_a


def update_end_of_season(elos):
    """Regression towards the mean
    
    Following 538 nfl methods
    https://fivethirtyeight.com/datalab/nfl-elo-ratings-are-back/
    """
    diff_from_mean = elos - np.mean(elos)
    elos -= diff_from_mean/3
    return elos

# %%
def create_team_frame(frame, elo=1000):
    teams = pd.DataFrame(pd.unique(frame[['home_team', 'away_team']].values.ravel('K')), columns=['team'])   
    teams.loc[:, 'elo']  = elo
    return teams

def calculate_numeric_result(entry):
    home_goal = int(entry.split(' - ')[0])
    away_goal = int(entry.split(' - ')[1])
    if home_goal > away_goal:
        return 1
    elif home_goal == away_goal:
        return 0.5
    else:
        return 0

def calculate_result(row):
    result = row.score_name
    if result == 'Any Other Home Win':
        return 1
    elif result == 'Any Other Away Win':
        return 0
    elif result == 'Any Other Draw':
        return 0.5
    elif result == 'Any unquoted':
        return 0.5
    else:
        return calculate_numeric_result(result)

# %%
df.loc[:, 'home_elo'] = 1000.
df.loc[:, 'away_elo'] = 1000.
df.loc[:, 'other_home_elo'] = 1000.
df.loc[:, 'other_away_elo'] = 1000.
df.loc[:, 'final_home_elo'] = 1000.
df.loc[:, 'final_away_elo'] = 1000.
season_frame = create_team_frame(df)
other_season_frame = create_team_frame(df)
final_season_frame = create_team_frame(df)
for index, row in df.iterrows():
    home = row.home_team
    away = row.away_team
    home_elo = season_frame[season_frame.team == home].elo.values[0]
    away_elo = season_frame[season_frame.team == away].elo.values[0]
    other_home_elo = other_season_frame[other_season_frame.team == home].elo.values[0]
    other_away_elo = other_season_frame[other_season_frame.team == away].elo.values[0]
    final_home_elo = final_season_frame[final_season_frame.team == home].elo.values[0]
    final_away_elo = final_season_frame[final_season_frame.team == away].elo.values[0]        
    df.loc[df.event_id == row.event_id, 'home_elo'] = home_elo
    df.loc[df.event_id == row.event_id, 'away_elo'] = away_elo
    df.loc[df.event_id == row.event_id, 'other_home_elo'] = other_home_elo
    df.loc[df.event_id == row.event_id, 'other_away_elo'] = other_away_elo    
    df.loc[df.event_id == row.event_id, 'final_home_elo'] = final_home_elo
    df.loc[df.event_id == row.event_id, 'final_away_elo'] = final_away_elo        
    expected_results = expected_result(home_elo, away_elo, elo_width)
    other_expected_results = expected_result(other_home_elo, other_away_elo, elo_width + 400)
    final_expected_results = expected_result(final_home_elo, final_away_elo, elo_width - 200)    
    result = calculate_result(row)
    new_home_elo, new_away_elo = calculate_new_elos(home_elo, away_elo, result, k_factor, elo_width)
    other_new_home_elo, other_new_away_elo = calculate_new_elos(other_home_elo, other_away_elo, result, k_factor, elo_width+400)
    final_new_home_elo, final_new_away_elo = calculate_new_elos(final_home_elo, final_away_elo, result, k_factor, elo_width-200)    
    season_frame.loc[season_frame.team == home, 'elo'] = new_home_elo
    season_frame.loc[season_frame.team == away, 'elo'] = new_away_elo
    other_season_frame.loc[other_season_frame.team == home, 'elo'] = other_new_home_elo
    other_season_frame.loc[other_season_frame.team == away, 'elo'] = other_new_away_elo
    final_season_frame.loc[final_season_frame.team == home, 'elo'] = final_new_home_elo
    final_season_frame.loc[final_season_frame.team == away, 'elo'] = final_new_away_elo

# %%
df[['event_name', 'event_id', 'open_date']].drop_duplicates().shape
# Out:
# (25031, 3)

# %%
df.sort_values(by='home_elo').head()
# Out:
#                            event_name  event_id           open_date  \
# 19268  North Ferriby Utd v Boston Utd  28543909 2018-01-20 15:00:00
# 19923   North Ferriby Utd v Southport  28581212 2018-02-17 15:00:00
# 19566  North Ferriby Utd v Leamington  28560969 2018-02-03 15:00:00
# 20158         Cowdenbeath v Peterhead  28591974 2018-02-24 15:00:00
# 20574             Cowdenbeath v Elgin  28624513 2018-03-17 15:00:00
#
#                score_name          home_team   away_team    home_elo  \
# 19268  Any Other Away Win  North Ferriby Utd  Boston Utd  741.818654
# 19923               0 - 3  North Ferriby Utd   Southport  743.758148
# 19566               1 - 1  North Ferriby Utd  Leamington  746.933582
# 20158               0 - 2        Cowdenbeath   Peterhead  751.852184
# 20574               3 - 1        Cowdenbeath       Elgin  752.345995
#
#           away_elo  other_home_elo  other_away_elo  final_home_elo  \
# 19268   985.533270      632.304319      941.752660      838.095384
# 19923   939.237792      624.198659      849.141333      845.699981
# 19566   990.294107      632.420550     1012.879264      847.238494
# 20158  1016.885075      650.575336     1041.298908      836.438821
# 20574   939.729064      646.630615      939.229032      841.791866
#
#        final_away_elo
# 19268     1022.722135
# 19923      994.844908
# 19566      980.434835
# 20158      996.294351
# 20574      959.075136

# %%
df.sort_values(by='home_elo', ascending=False).head()
# Out:
#                     event_name  event_id           open_date  \
# 22228  Man City v Huddersfield  28824829 2018-08-19 12:30:00
# 15014            Celtic v Lyon  28306512 2017-07-15 14:00:00
# 23248          Man City v Lyon  28880548 2018-09-19 19:00:00
# 22887     Man City v Newcastle  28854367 2018-09-01 16:30:00
# 24651      Man City v Shakhtar  28974151 2018-11-07 20:00:00
#
#                score_name home_team     away_team     home_elo     away_elo  \
# 22228               6 - 1  Man City  Huddersfield  1410.163957  1069.134611
# 15014  Any Other Away Win    Celtic          Lyon  1409.009169   971.443550
# 23248               1 - 2  Man City          Lyon  1407.409590  1026.732961
# 22887               2 - 1  Man City     Newcastle  1403.098891  1079.993199
# 24651               6 - 0  Man City      Shakhtar  1401.287688   995.202096
#
#        other_home_elo  other_away_elo  final_home_elo  final_away_elo
# 22228     1609.884822     1057.571518     1258.088813     1071.602128
# 15014     1593.766378      969.785864     1266.884093      974.338501
# 23248     1612.570805     1018.297121     1251.384851     1034.386958
# 22887     1606.347055     1112.613022     1248.482610     1048.257397
# 24651     1618.825038      992.762581     1239.099085      997.009903

# %%
df.loc[:, 'home_team_goal'] = df.score_name.apply(lambda x: int(x.split(' - ')[0]) if len(x.split(' - ')) > 1 else None)
df.loc[:, 'away_team_goal'] = df.score_name.apply(lambda x: int(x.split(' - ')[1]) if len(x.split(' - ')) > 1 else None)
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  other_home_elo  other_away_elo  final_home_elo  final_away_elo  \
# 6     1000.0          1000.0          1000.0          1000.0          1000.0
# 93    1000.0          1000.0          1000.0          1000.0          1000.0
# 17    1000.0          1000.0          1000.0          1000.0          1000.0
# 59    1000.0          1000.0          1000.0          1000.0          1000.0
# 58    1000.0          1000.0          1000.0          1000.0          1000.0
#
#     home_team_goal  away_team_goal
# 6              1.0             3.0
# 93             NaN             NaN
# 17             5.0             0.0
# 59             1.0             2.0
# 58             4.0             2.0

# %%
HOME_TEAM_BASE = np.mean(df.home_team_goal)
AWAY_TEAM_BASE = np.mean(df.away_team_goal)

k_factor = 32
score_k_factor = 0.05

def calculate_new_elos_score(rating_a, rating_b, score_a, home, k_factor):
    """Calculates and returns the new Elo ratings for two players.
    score_a is 1 for a win by player A, 0 for a loss by player A, or 0.5 for a draw.
    """
    if home:
        e_a = expected_result_score(rating_a, rating_b, HOME_TEAM_BASE)
    else:
        e_a = expected_result_score(rating_a, rating_b, AWAY_TEAM_BASE)
    new_rating_a = rating_a + (k_factor * (score_a - e_a))
    new_rating_b = rating_b + (k_factor * (score_a - e_a))
    return new_rating_a, new_rating_b
    

def expected_result_score(elo_a, elo_b, base):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expect_a = (elo_a/base) * (elo_b/base) * base
    return expect_a


def update_end_of_season(elos):
    """Regression towards the mean
    
    Following 538 nfl methods
    https://fivethirtyeight.com/datalab/nfl-elo-ratings-are-back/
    """
    diff_from_mean = elos - np.mean(elos)
    elos -= diff_from_mean/3
    return elos

# %%
def get_elos(frame, names):
    return [frame[frame.team == entry].elo.values[0] for entry in names]

#df.loc[:, 'home_elo'] = 1000.
#df.loc[:, 'away_elo'] = 1000.
df.loc[:, 'home_attack_elo'] = HOME_TEAM_BASE
df.loc[:, 'home_defence_elo'] = AWAY_TEAM_BASE
df.loc[:, 'away_attack_elo'] = AWAY_TEAM_BASE
df.loc[:, 'away_defence_elo'] = HOME_TEAM_BASE


#season_frame = create_team_frame(df)
home_attack_frame = create_team_frame(df, HOME_TEAM_BASE)
home_defence_frame = create_team_frame(df, AWAY_TEAM_BASE)
away_attack_frame = create_team_frame(df, AWAY_TEAM_BASE)
away_defence_frame = create_team_frame(df, HOME_TEAM_BASE)

i = 0

for index, row in df.iterrows():
    if i % 1000 == 0:
        print(i)
    i += 1
    home = row.home_team
    away = row.away_team
    home_team_goals = row.home_team_goal
    away_team_goals = row.away_team_goal
    
#    home_elo, away_elo = get_elos(season_frame, (home, away))
    home_attack_elo = get_elos(home_attack_frame, (home,))[0]
    home_defence_elo = get_elos(home_defence_frame, (home,))[0]
    away_attack_elo = get_elos(away_attack_frame, (away,))[0]
    away_defence_elo = get_elos(away_defence_frame, (away,))[0]
        
#    df.loc[df.event_id == row.event_id, 'home_elo'] = home_elo
#    df.loc[df.event_id == row.event_id, 'away_elo'] = away_elo
    df.loc[df.event_id == row.event_id, 'home_attack_elo'] = home_attack_elo
    df.loc[df.event_id == row.event_id, 'away_attack_elo'] = away_attack_elo
    df.loc[df.event_id == row.event_id, 'home_defence_elo'] = home_defence_elo
    df.loc[df.event_id == row.event_id, 'away_defence_elo'] = away_defence_elo  
        
    expected_results = expected_result(home_elo, away_elo, elo_width)
    result = calculate_result(row)
#    new_home_elo, new_away_elo = calculate_new_elos(home_elo, away_elo, result, k_factor, elo_width)
#    season_frame.loc[season_frame.team == home, 'elo'] = new_home_elo
#    season_frame.loc[season_frame.team == away, 'elo'] = new_away_elo  
    
    if (not pd.isna(home_team_goals)) and (not pd.isna(away_team_goals)):
        new_home_attack_elo, new_away_defence_elo = calculate_new_elos_score(home_attack_elo, away_defence_elo, home_team_goals, True, score_k_factor)
        new_away_attack_elo, new_home_defence_elo = calculate_new_elos_score(away_attack_elo, home_defence_elo, away_team_goals, False, score_k_factor)        
        home_attack_frame.loc[home_attack_frame.team == home, 'elo'] = new_home_attack_elo
        home_defence_frame.loc[home_defence_frame.team == home, 'elo'] = new_home_defence_elo
        away_attack_frame.loc[away_attack_frame.team == away, 'elo'] = new_away_attack_elo
        away_defence_frame.loc[away_defence_frame.team == away, 'elo'] = new_away_defence_elo
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000

# %%
home_attack_frame[pd.isnull(home_attack_frame.elo)]
# Out:
# Empty DataFrame
# Columns: [team, elo]
# Index: []

# %%
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  other_home_elo  other_away_elo  final_home_elo  final_away_elo  \
# 6     1000.0          1000.0          1000.0          1000.0          1000.0
# 93    1000.0          1000.0          1000.0          1000.0          1000.0
# 17    1000.0          1000.0          1000.0          1000.0          1000.0
# 59    1000.0          1000.0          1000.0          1000.0          1000.0
# 58    1000.0          1000.0          1000.0          1000.0          1000.0
#
#     home_team_goal  away_team_goal  home_attack_elo  home_defence_elo  \
# 6              1.0             3.0         1.359675          1.182145
# 93             NaN             NaN         1.359675          1.182145
# 17             5.0             0.0         1.359675          1.182145
# 59             1.0             2.0         1.359675          1.182145
# 58             4.0             2.0         1.359675          1.182145
#
#     away_attack_elo  away_defence_elo
# 6          1.182145          1.359675
# 93         1.182145          1.359675
# 17         1.182145          1.359675
# 59         1.182145          1.359675
# 58         1.182145          1.359675

# %%
df.sort_values(by='home_attack_elo', ascending=False).head()
# Out:
#                  event_name  event_id           open_date score_name  \
# 24651   Man City v Shakhtar  28974151 2018-11-07 20:00:00      6 - 0
# 22887  Man City v Newcastle  28854367 2018-09-01 16:30:00      2 - 1
# 23248       Man City v Lyon  28880548 2018-09-19 19:00:00      1 - 2
# 24296     Man City v Fulham  28949910 2018-11-01 19:45:00      2 - 0
# 20012    Man City v Chelsea  28585883 2018-03-04 16:00:00      1 - 0
#
#       home_team  away_team     home_elo     away_elo  other_home_elo  \
# 24651  Man City   Shakhtar  1401.287688   995.202096     1618.825038
# 22887  Man City  Newcastle  1403.098891  1079.993199     1606.347055
# 23248  Man City       Lyon  1407.409590  1026.732961     1612.570805
# 24296  Man City     Fulham  1390.967119  1126.327694     1605.716947
# 20012  Man City    Chelsea  1373.156640  1239.511180     1555.897331
#
#        other_away_elo  final_home_elo  final_away_elo  home_team_goal  \
# 24651      992.762581     1239.099085      997.009903             6.0
# 22887     1112.613022     1248.482610     1048.257397             2.0
# 23248     1018.297121     1251.384851     1034.386958             1.0
# 24296     1183.629592     1230.636218     1070.524903             2.0
# 20012     1418.335176     1228.060929     1115.331541             1.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 24651             0.0         3.029895          0.683013         1.141061
# 22887             1.0         2.921392          0.720163         1.267457
# 23248             2.0         2.892597          0.731556         1.120381
# 24296             0.0         2.882054          0.720138         1.680823
# 20012             0.0         2.879443          0.658609         1.936112
#
#        away_defence_elo
# 24651          1.340753
# 22887          1.198873
# 23248          1.382396
# 24296          1.475655
# 20012          0.855453

# %%
df.sort_values(by='away_attack_elo', ascending=False).head()
# Out:
#                    event_name  event_id           open_date score_name  \
# 23376   Oxford Utd v Man City  28887113 2018-09-25 18:45:00      0 - 3
# 23645    Liverpool v Man City  28906153 2018-10-07 15:30:00      0 - 0
# 21543  Southampton v Man City  28694904 2018-05-13 14:00:00      0 - 1
# 22715       Wolves v Man City  28845369 2018-08-25 11:30:00      1 - 1
# 21784      Arsenal v Man City  28766966 2018-08-12 15:00:00      0 - 2
#
#          home_team away_team     home_elo     away_elo  other_home_elo  \
# 23376   Oxford Utd  Man City   957.001975  1383.753316      948.305667
# 23645    Liverpool  Man City  1276.415383  1391.785574     1415.704156
# 21543  Southampton  Man City  1122.527736  1386.532533     1123.836890
# 22715       Wolves  Man City  1120.931960  1414.104101     1175.602604
# 21784      Arsenal  Man City  1205.686049  1402.363592     1328.102575
#
#        other_away_elo  final_home_elo  final_away_elo  home_team_goal  \
# 23376     1592.402677      986.090243     1225.511921             0.0
# 23645     1604.009220     1178.525458     1232.157736             0.0
# 21543     1580.813078     1104.817389     1237.438378             0.0
# 22715     1615.306523     1065.848160     1261.436372             1.0
# 21784     1599.841248     1129.153372     1251.820722             0.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 23376             3.0         1.494509          1.395823         2.773566
# 23645             0.0         2.574000          0.739038         2.759821
# 21543             1.0         1.214888          0.967319         2.681761
# 22715             1.0         1.736459          0.838059         2.671427
# 21784             2.0         2.840681          0.704898         2.650448
#
#        away_defence_elo
# 23376          0.486744
# 23645          0.459993
# 21543          0.628548
# 22715          0.495721
# 21784          0.553545

# %%
df.sort_values(by='home_defence_elo', ascending=True).head()
# Out:
#                   event_name  event_id           open_date score_name  \
# 17654    Man Utd v Newcastle  28457655 2017-11-18 17:30:00      4 - 1
# 17417      Man Utd v Benfica  28439904 2017-10-31 19:45:00      2 - 0
# 15888       Man Utd v Burton  28360635 2017-09-20 19:00:00      4 - 1
# 18253  Man Utd v CSKA Moscow  28490325 2017-12-05 19:45:00      2 - 1
# 16063      Man Utd v Everton  28371686 2017-09-17 15:00:00      4 - 0
#
#       home_team    away_team     home_elo     away_elo  other_home_elo  \
# 17654   Man Utd    Newcastle  1278.142452  1111.019805     1407.370068
# 17417   Man Utd      Benfica  1287.412427   978.715539     1414.671428
# 15888   Man Utd       Burton  1271.630356  1032.793270     1389.359149
# 18253   Man Utd  CSKA Moscow  1280.217854   995.410091     1414.943464
# 16063   Man Utd      Everton  1261.050888  1138.504313     1378.018154
#
#        other_away_elo  final_home_elo  final_away_elo  home_team_goal  \
# 17654     1166.626819     1178.673520     1066.637135             4.0
# 17417      975.956458     1191.192459      981.520459             2.0
# 15888     1019.455318     1187.227090     1047.043794             4.0
# 18253      991.562595     1176.389972     1000.293829             2.0
# 16063     1169.651542     1178.150387     1097.680592             4.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 17654             1.0         2.078745          0.248318         1.273462
# 17417             0.0         2.096722          0.261455         1.187967
# 15888             1.0         1.906479          0.269287         0.933733
# 18253             1.0         2.180426          0.270558         1.163544
# 16063             0.0         1.773728          0.284694         1.279554
#
#        away_defence_elo
# 17654          0.998069
# 17417          1.530109
# 15888          1.418433
# 18253          1.392784
# 16063          1.031004

# %%
df.sort_values(by='home_defence_elo', ascending=False).head()
# Out:
#                       event_name  event_id           open_date  \
# 3837         Kilmarnock v Hearts  27637421 2016-01-02 15:00:00
# 4023   Kilmarnock v Inverness CT  27647791 2016-01-16 15:00:00
# 15388           E Stirling v Ayr  28340242 2017-08-16 18:45:00
# 9832          E Stirling v Annan  27989543 2016-10-29 14:00:00
# 4244       Kilmarnock v Hamilton  27663911 2016-01-30 15:00:00
#
#                score_name   home_team     away_team    home_elo     away_elo  \
# 3837                2 - 2  Kilmarnock        Hearts  928.619463  1063.298635
# 4023                2 - 1  Kilmarnock  Inverness CT  955.814043  1026.981717
# 15388  Any Other Away Win  E Stirling           Ayr  863.611049  1022.794363
# 9832                1 - 2  E Stirling         Annan  822.786374   951.916996
# 4244                0 - 1  Kilmarnock      Hamilton  954.519158   936.940786
#
#        other_home_elo  other_away_elo  final_home_elo  final_away_elo  \
# 3837       912.394425     1072.538641      948.376222     1047.801652
# 4023       935.285310     1028.743181      979.816388     1025.108699
# 15388      798.063635     1017.306995      923.892201     1035.717184
# 9832       764.052828      945.459200      878.052415      958.923709
# 4244       934.632788      928.704351      977.140820      950.544900
#
#        home_team_goal  away_team_goal  home_attack_elo  home_defence_elo  \
# 3837              2.0             2.0         1.341127          1.965830
# 4023              2.0             1.0         1.383820          1.962949
# 15388             NaN             NaN         0.868180          1.912560
# 9832              1.0             2.0         0.861291          1.911525
# 4244              0.0             1.0         1.415446          1.905959
#
#        away_attack_elo  away_defence_elo
# 3837          1.237337          1.162005
# 4023          1.288653          1.343607
# 15388         1.266984          1.277990
# 9832          1.224057          1.361124
# 4244          1.174655          1.710177

# %%
df.sort_values(by='away_defence_elo', ascending=True).head()
# Out:
#                   event_name  event_id           open_date score_name  \
# 23645   Liverpool v Man City  28906153 2018-10-07 15:30:00      0 - 0
# 23376  Oxford Utd v Man City  28887113 2018-09-25 18:45:00      0 - 3
# 22715      Wolves v Man City  28845369 2018-08-25 11:30:00      1 - 1
# 23133     Cardiff v Man City  28875069 2018-09-22 14:00:00      0 - 5
# 21784     Arsenal v Man City  28766966 2018-08-12 15:00:00      0 - 2
#
#         home_team away_team     home_elo     away_elo  other_home_elo  \
# 23645   Liverpool  Man City  1276.415383  1391.785574     1415.704156
# 23376  Oxford Utd  Man City   957.001975  1383.753316      948.305667
# 22715      Wolves  Man City  1120.931960  1414.104101     1175.602604
# 23133     Cardiff  Man City  1090.836106  1378.626547     1138.895148
# 21784     Arsenal  Man City  1205.686049  1402.363592     1328.102575
#
#        other_away_elo  final_home_elo  final_away_elo  home_team_goal  \
# 23645     1604.009220     1178.525458     1232.157736             0.0
# 23376     1592.402677      986.090243     1225.511921             0.0
# 22715     1615.306523     1065.848160     1261.436372             1.0
# 23133     1585.470147     1044.986301     1221.816173             0.0
# 21784     1599.841248     1129.153372     1251.820722             0.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 23645             0.0         2.574000          0.739038         2.759821
# 23376             3.0         1.494509          1.395823         2.773566
# 22715             1.0         1.736459          0.838059         2.671427
# 23133             5.0         1.445318          0.928599         2.626734
# 21784             2.0         2.840681          0.704898         2.650448
#
#        away_defence_elo
# 23645          0.459993
# 23376          0.486744
# 22715          0.495721
# 23133          0.514066
# 21784          0.553545

# %%
df.loc[:, 'expected_home_goals'] = df.apply(lambda x: expected_result_score(x.home_attack_elo, x.away_defence_elo, HOME_TEAM_BASE), axis=1)
df.loc[:, 'expected_away_goals'] = df.apply(lambda x: expected_result_score(x.away_attack_elo, x.home_defence_elo, AWAY_TEAM_BASE), axis=1)
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  other_home_elo  other_away_elo  final_home_elo  final_away_elo  \
# 6     1000.0          1000.0          1000.0          1000.0          1000.0
# 93    1000.0          1000.0          1000.0          1000.0          1000.0
# 17    1000.0          1000.0          1000.0          1000.0          1000.0
# 59    1000.0          1000.0          1000.0          1000.0          1000.0
# 58    1000.0          1000.0          1000.0          1000.0          1000.0
#
#     home_team_goal  away_team_goal  home_attack_elo  home_defence_elo  \
# 6              1.0             3.0         1.359675          1.182145
# 93             NaN             NaN         1.359675          1.182145
# 17             5.0             0.0         1.359675          1.182145
# 59             1.0             2.0         1.359675          1.182145
# 58             4.0             2.0         1.359675          1.182145
#
#     away_attack_elo  away_defence_elo  expected_home_goals  \
# 6          1.182145          1.359675             1.359675
# 93         1.182145          1.359675             1.359675
# 17         1.182145          1.359675             1.359675
# 59         1.182145          1.359675             1.359675
# 58         1.182145          1.359675             1.359675
#
#     expected_away_goals
# 6              1.182145
# 93             1.182145
# 17             1.182145
# 59             1.182145
# 58             1.182145

# %%
def replace_score_name(val):
    try:
        home_score = int(val.split(' - ')[0])
        away_score = int(val.split(' - ')[1])
        if home_score <= 3 and away_score <= 3:
            return val
        elif home_score > away_score:
            return "Any Other Home Win"
        elif home_score == away_score:
            return "Any Other Draw"
        elif away_score > home_score:
            return "Any Other Away Win"
        else:
            return val
    except:
        return val
    
df.loc[:, 'modified_score_name'] = df.score_name.apply(lambda x: replace_score_name(x))
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  other_home_elo  other_away_elo         ...           \
# 6     1000.0          1000.0          1000.0         ...
# 93    1000.0          1000.0          1000.0         ...
# 17    1000.0          1000.0          1000.0         ...
# 59    1000.0          1000.0          1000.0         ...
# 58    1000.0          1000.0          1000.0         ...
#
#     final_away_elo  home_team_goal  away_team_goal  home_attack_elo  \
# 6           1000.0             1.0             3.0         1.359675
# 93          1000.0             NaN             NaN         1.359675
# 17          1000.0             5.0             0.0         1.359675
# 59          1000.0             1.0             2.0         1.359675
# 58          1000.0             4.0             2.0         1.359675
#
#     home_defence_elo  away_attack_elo  away_defence_elo  expected_home_goals  \
# 6           1.182145         1.182145          1.359675             1.359675
# 93          1.182145         1.182145          1.359675             1.359675
# 17          1.182145         1.182145          1.359675             1.359675
# 59          1.182145         1.182145          1.359675             1.359675
# 58          1.182145         1.182145          1.359675             1.359675
#
#     expected_away_goals  modified_score_name
# 6              1.182145                1 - 3
# 93             1.182145   Any Other Away Win
# 17             1.182145   Any Other Home Win
# 59             1.182145                1 - 2
# 58             1.182145   Any Other Home Win
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Building Models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

new_df = df[(df.home_team_goal >= 0) & (df.away_team_goal >= 0)]
X_train, X_test, y_train, y_test = train_test_split(new_df[[
    'home_elo', 'away_elo', 'other_home_elo', 'other_away_elo', 'final_home_elo', 'final_away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'
]].values,
    new_df.home_team_goal, test_size=0.15, random_state=42)

# %%
lr = LinearRegression()

lr.fit(
    X_train,
    y_train
)

testy = lr.predict(X_test)
testy
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/base.py:485: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)
# array([1.34459777, 1.4760747 , 1.3560383 , ..., 1.23834851, 1.37275909,
#        0.99541587])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, testy)
# Out:
# 1.0970991222483102

# %%
lr.coef_
# Out:
# array([-1.50715397e-03,  1.18561690e-03,  4.60124083e-04, -1.12814594e-04,
#         3.11210088e-03, -3.82813979e-03, -2.17235988e-03, -2.39747362e-01,
#        -1.93657425e-01, -2.73872803e-01,  5.76422506e-01,  2.32568588e-01])

# %%
from scipy.stats import poisson

x = np.arange(0, 8)
new_df.expected_home_goals.apply(lambda y: poisson.pmf(x, y)[0]).head()
# Out:
# 6     0.256744
# 17    0.256744
# 59    0.256744
# 58    0.256744
# 60    0.256744
# Name: expected_home_goals, dtype: float64

# %%
values = new_df.home_team_goal.values
probs = [poisson.pmf(x, e) for e in new_df.expected_home_goals.values]

# %%
from sklearn.metrics import log_loss
home_values = new_df.home_team_goal.values
home_probs = [poisson.pmf(x, e) for e in new_df.expected_home_goals.values]
log_loss(home_values, home_probs)
# Out:
# 1.436965886990492

# %%
away_values = new_df.away_team_goal.values
away_probs = [poisson.pmf(x, e) for e in new_df.expected_away_goals.values]
log_loss(away_values, away_probs)
# Out:
# 1.3686918777261627

# %%
import xgboost

# %%
reg = xgboost.XGBRegressor(
    objective='count:poisson',
    max_depth=2,
    n_estimators=50,
    booster='gbtree',
    colsample_bytree=0.8,
    subsample=0.6,
)

# %%
reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=50,
#        n_jobs=1, nthread=None, objective='count:poisson', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.6)

# %%
preds = reg.predict(X_test)
preds
# Out:
# array([1.330007 , 1.4897834, 1.2488201, ..., 1.299124 , 1.4114867,
#        1.1013286], dtype=float32)

# %%
X_test[0]
# Out:
# array([1015.851318  , 1046.56680555, 1015.96026952, 1047.27242565,
#        1015.47985519, 1045.24492734,    1.49362638,    1.25854199,
#           1.27380118,    1.3336947 ,    1.46508654,    1.35612095])

# %%
handy = [poisson.pmf(x, e) for e in preds]
log_loss(y_test, handy)
# Out:
# 1.427855563990286

# %%
[(i, 100*e/sum(handy[0])) for i, e in enumerate(handy[0])]
# Out:
# [(0, 26.44952977389612),
#  (1, 35.17805861009241),
#  (2, 23.393531343540563),
#  (3, 10.371186478990996),
#  (4, 3.4484375424909595),
#  (5, 0.9172891844959306),
#  (6, 0.20333349950168408),
#  (7, 0.0386335669913434)]

# %% [markdown]
# ## Getting serious

# %%
new_df.head()
# Out:
#                 event_name  event_id           open_date score_name  \
# 6      Leicester v Chelsea  27425814 2015-04-29 18:45:00      1 - 3
# 17         Celtic v Dundee  27428357 2015-05-01 18:45:00      5 - 0
# 59  Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00      1 - 2
# 58        Norwich v Fulham  27428774 2015-05-02 11:15:00      4 - 2
# 60     Watford v Sheff Wed  27428776 2015-05-02 11:15:00      1 - 1
#
#        home_team  away_team  home_elo  away_elo  other_home_elo  \
# 6      Leicester    Chelsea    1000.0    1000.0          1000.0
# 17        Celtic     Dundee    1000.0    1000.0          1000.0
# 59  Nottm Forest    Cardiff    1000.0    1000.0          1000.0
# 58       Norwich     Fulham    1000.0    1000.0          1000.0
# 60       Watford  Sheff Wed    1000.0    1000.0          1000.0
#
#     other_away_elo         ...           final_away_elo  home_team_goal  \
# 6           1000.0         ...                   1000.0             1.0
# 17          1000.0         ...                   1000.0             5.0
# 59          1000.0         ...                   1000.0             1.0
# 58          1000.0         ...                   1000.0             4.0
# 60          1000.0         ...                   1000.0             1.0
#
#     away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 6              3.0         1.359675          1.182145         1.182145
# 17             0.0         1.359675          1.182145         1.182145
# 59             2.0         1.359675          1.182145         1.182145
# 58             2.0         1.359675          1.182145         1.182145
# 60             1.0         1.359675          1.182145         1.182145
#
#     away_defence_elo  expected_home_goals  expected_away_goals  \
# 6           1.359675             1.359675             1.182145
# 17          1.359675             1.359675             1.182145
# 59          1.359675             1.359675             1.182145
# 58          1.359675             1.359675             1.182145
# 60          1.359675             1.359675             1.182145
#
#     modified_score_name
# 6                 1 - 3
# 17   Any Other Home Win
# 59                1 - 2
# 58   Any Other Home Win
# 60                1 - 1
#
# [5 rows x 21 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest

# %%
pipeline = Pipeline(
    [
#        ('scaler', StandardScaler(with_mean=True, with_std=True)),
#        ('poly', PolynomialFeatures()),
        ('gb', xgboost.XGBRegressor(objective='count:poisson'))
    ]
)

parameters = {}
#parameters['scaler__with_mean'] = [True, False]
#parameters['scaler__with_std'] = [True, False]
#parameters['poly__degree'] = [2, 3]
#parameters['poly__iteraction_only'] = [True, False]
parameters['gb__eta'] = [0.01]
parameters['gb__max_depth'] = [2]
parameters['gb__n_estimators'] = [70]
parameters['gb__subsample'] = [0.95]
#parameters['gb__colsample_by_tree'] = [0, 0.1]


CV = GridSearchCV(pipeline, parameters, cv=3, n_jobs=2)
CV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('gb', XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='count:poisson', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1))]),
#        fit_params=None, iid='warn', n_jobs=2,
#        param_grid={'gb__eta': [0.01], 'gb__max_depth': [2], 'gb__n_estimators': [70], 'gb__subsample': [0.95]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
CV.best_score_
# Out:
# 0.04328972577274026

# %%
CV.best_params_
# Out:
# {'gb__eta': 0.01,
#  'gb__max_depth': 2,
#  'gb__n_estimators': 70,
#  'gb__subsample': 0.95}

# %%
y_pred = CV.predict(X_test)
handy = [poisson.pmf(x, e) for e in y_pred]
log_loss(y_test, handy)
# Out:
# 1.4286331061895186

# %% [markdown]
# ## Away Goals

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df[['home_elo', 'away_elo', 'other_home_elo', 'other_away_elo', 'final_home_elo', 'final_away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals']].values,
    new_df.away_team_goal, test_size=0.15, random_state=23)

pipeline = Pipeline(
    [
#        ('scaler', StandardScaler(with_mean=True, with_std=True)),
#        ('poly', PolynomialFeatures()),
        ('gb', xgboost.XGBRegressor(objective='count:poisson'))
    ]
)

parameters = {}
#parameters['scaler__with_mean'] = [False]
#parameters['scaler__with_std'] = [True, False]
#parameters['poly__degree'] = [2, 3]
#parameters['poly__iteraction_only'] = [True, False]
parameters['gb__max_depth'] = [2]
parameters['gb__n_estimators'] = [50]
parameters['gb__subsample'] = [0.95]
parameters['gb__colsample_by_tree'] = [0.0]
parameters['gb__eta'] = [0.01]
#parameters['gb__booster'] = ['gbtree']


CV_a = GridSearchCV(pipeline, parameters, cv=3, n_jobs=2)
CV_a.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('gb', XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='count:poisson', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1))]),
#        fit_params=None, iid='warn', n_jobs=2,
#        param_grid={'gb__max_depth': [2], 'gb__n_estimators': [50], 'gb__subsample': [0.95], 'gb__colsample_by_tree': [0.0], 'gb__eta': [0.01]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
CV_a.best_score_
# Out:
# 0.041236366632325994

# %%
CV_a.best_params_
# Out:
# {'gb__colsample_by_tree': 0.0,
#  'gb__eta': 0.01,
#  'gb__max_depth': 2,
#  'gb__n_estimators': 50,
#  'gb__subsample': 0.95}

# %%
y_pred = CV_a.predict(X_test)
handy = [poisson.pmf(x, e) for e in y_pred]
log_loss(y_test, handy)
# Out:
# 1.344373945972899

# %% [markdown]
# ## Testing

# %%
conn = psycopg2.connect("dbname=football")
cur = conn.cursor()

sql = """
SELECT
    a.event_name,
    a.name,
    a.ltp AS lay_ltp,
    a.odds AS lay_odds,
    a.vol AS lay_vol,
    a.pct_chance AS lay_pct_chance,
    b.ltp AS back_ltp,
    b.odds AS back_odds,
    b.vol AS back_vol,
    b.pct_chance AS back_pct_chance
FROM
last_correct_score_lay_odds a
INNER JOIN
last_correct_score_back_odds b
ON a.event_name = b.event_name
AND a.mc_id = b.mc_id
AND a.open_date = b.open_date
AND a.rc_id = b.rc_id
"""

cur.execute(sql)

recent_odds = cur.fetchall()
recent_colnames = [desc[0] for desc in cur.description]
conn.close()

# %%
odds_df = pd.DataFrame(recent_odds, columns=recent_colnames)
odds_df.head()
# Out:
#   event_name   name lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp  \
# 0   18746827  0 - 0     0.0       60    9.66  1.6666666666666667      0.0
# 1   18746827  1 - 0     0.0       24   21.11  4.1666666666666667      0.0
# 2   18746827  1 - 1     0.0       17   26.53  5.8823529411764706      0.0
# 3   18746827  0 - 1     0.0       46    1.57  2.1739130434782609      0.0
# 4   18746827  2 - 0     0.0       18    10.2  5.5555555555555556      0.0
#
#   back_odds back_vol     back_pct_chance
# 0        30      6.9  3.3333333333333333
# 1      13.5       16  7.4074074074074074
# 2      12.5        4  8.0000000000000000
# 3        27     7.69  3.7037037037037037
# 4      12.5    21.38  8.0000000000000000

# %%
odds_df.columns = [
    'event_name',
    'score_name',
    'lay_ltp',
    'lay_odds',
    'lay_vol',
    'lay_pct_chance',
    'back_ltp',
    'back_odds',
    'back_vol',
    'back_pct_chance'
]

# %%
odds_df.tail()
# Out:
#               event_name          score_name lay_ltp lay_odds lay_vol  \
# 10473  Yeovil v Tranmere               2 - 3     0.0       42   29.49
# 10474  Yeovil v Tranmere               1 - 3     0.0       30   58.47
# 10475  Yeovil v Tranmere               0 - 3     0.0       42   42.62
# 10476  Yeovil v Tranmere  Any Other Home Win    26.0       28   59.15
# 10477  Yeovil v Tranmere  Any Other Away Win     0.0       26   11.46
#
#            lay_pct_chance back_ltp back_odds back_vol     back_pct_chance
# 10473  2.3809523809523810      0.0        38    14.24  2.6315789473684211
# 10474  3.3333333333333333      0.0        27    17.49  3.7037037037037037
# 10475  2.3809523809523810      0.0        36    23.99  2.7777777777777778
# 10476  3.5714285714285714     23.0        23     9.11  4.3478260869565217
# 10477  3.8461538461538462     22.0        22    26.05  4.5454545454545455

# %%
current = new_df[(new_df.open_date >= '2018-10-01') & (new_df.open_date < '2018-11-01')]
merged = current.merge(odds_df[odds_df.score_name != 'Any Other Draw'], how='inner', left_on='event_name', right_on='event_name')
merged = merged[[
    'event_name', 'score_name_x', 'modified_score_name', 'score_name_y', 'lay_ltp', 'lay_odds', 'lay_vol', 'lay_pct_chance', 'back_ltp', 'back_odds', 'back_vol', 'back_pct_chance',
    'home_elo', 'away_elo', 'other_home_elo', 'other_away_elo', 'final_home_elo', 'final_away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'    
]].drop_duplicates()
merged.head()
# Out:
#                      event_name score_name_x modified_score_name score_name_y  \
# 0  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        0 - 0
# 1  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 2  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
# 4  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 5  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
#
#   lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp back_odds  \
# 0     0.0       65    0.76  1.5384615384615385     12.0      12.5
# 1     0.0       24    0.76  4.1666666666666667      0.0       6.2
# 2     0.0       65    0.76  1.5384615384615385      0.0       8.2
# 4     0.0       24    0.76  4.1666666666666667      0.0       6.2
# 5     0.0       65    0.76  1.5384615384615385      0.0       8.2
#
#           ...          other_home_elo other_away_elo  final_home_elo  \
# 0         ...             1115.768837    1074.549018      1063.01772
# 1         ...             1115.768837    1074.549018      1063.01772
# 2         ...             1115.768837    1074.549018      1063.01772
# 4         ...             1115.768837    1074.549018      1063.01772
# 5         ...             1115.768837    1074.549018      1063.01772
#
#    final_away_elo  home_attack_elo  home_defence_elo  away_attack_elo  \
# 0     1034.999656           1.5883          0.991137         1.610078
# 1     1034.999656           1.5883          0.991137         1.610078
# 2     1034.999656           1.5883          0.991137         1.610078
# 4     1034.999656           1.5883          0.991137         1.610078
# 5     1034.999656           1.5883          0.991137         1.610078
#
#    away_defence_elo  expected_home_goals  expected_away_goals
# 0          1.327148             1.550304             1.349926
# 1          1.327148             1.550304             1.349926
# 2          1.327148             1.550304             1.349926
# 4          1.327148             1.550304             1.349926
# 5          1.327148             1.550304             1.349926
#
# [5 rows x 24 columns]

# %%
merged[merged.modified_score_name == 'Any Other Draw']
# Out:
# Empty DataFrame
# Columns: [event_name, score_name_x, modified_score_name, score_name_y, lay_ltp, lay_odds, lay_vol, lay_pct_chance, back_ltp, back_odds, back_vol, back_pct_chance, home_elo, away_elo, other_home_elo, other_away_elo, final_home_elo, final_away_elo, home_attack_elo, home_defence_elo, away_attack_elo, away_defence_elo, expected_home_goals, expected_away_goals]
# Index: []
#
# [0 rows x 24 columns]

# %%
def calculate_home_score_probabilities(test_row_values):
    y_pred_row = CV.predict(test_row_values)
    handy_row = [poisson.pmf(x, e) for e in y_pred_row][0]
    return handy_row

def calculate_away_score_probabilities(test_row_values):
    y_pred_row = CV_a.predict(test_row_values)
    handy_row = [poisson.pmf(x, e) for e in y_pred_row][0]
    return handy_row
    
def calculate_score_probabilities(row):
    prob = 0
    namey = row.score_name_y
    test_row = row[[
        'home_elo', 'away_elo', 'other_home_elo', 'other_away_elo', 'final_home_elo', 'final_away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'
    ]].values.reshape(1, -1)
    home_probs = calculate_home_score_probabilities(test_row)
    away_probs = calculate_away_score_probabilities(test_row)
    if namey == 'Any Other Home Win':
        for hg, ho in enumerate(home_probs):
            for ag, ao in enumerate(away_probs):
                if hg <= 3 and ag <= 3:
                    pass
                else:
                    if hg > ag:
                        prob += 100.*(ho / sum(home_probs)) * (ao / sum(away_probs))      
    elif namey == 'Any Other Away Win':
        for hg, ho in enumerate(home_probs):
            for ag, ao in enumerate(away_probs):
                if hg <= 3 and ag <= 3:
                    pass
                else:
                    if ag > hg:
                        prob += 100.*(ho / sum(home_probs)) * (ao / sum(away_probs))
    elif namey == 'Any Other Draw':
        for hg, ho in enumerate(home_probs):
            for ag, ao in enumerate(away_probs):
                if hg <= 3 and ag <= 3:
                    pass
                else:
                    if hg == ag:
                        prob += 100.*(ho / sum(home_probs)) * (ao / sum(away_probs))
    elif namey == 'Any Other Result':
        return prob
    else:
        home_g = int(namey.split('-')[0].strip())
        away_g = int(namey.split('-')[1].strip())
        prob = 100.*(home_probs[home_g] / sum(home_probs)) * (away_probs[away_g] / sum(away_probs))
    return prob

# %%
merged.loc[:, 'calculated_prob'] = merged.apply(lambda x: calculate_score_probabilities(x), axis=1, raw=True)
merged.head()
# Out:
#                      event_name score_name_x modified_score_name score_name_y  \
# 0  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        0 - 0
# 1  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 2  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
# 4  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 5  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
#
#   lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp back_odds  \
# 0     0.0       65    0.76  1.5384615384615385     12.0      12.5
# 1     0.0       24    0.76  4.1666666666666667      0.0       6.2
# 2     0.0       65    0.76  1.5384615384615385      0.0       8.2
# 4     0.0       24    0.76  4.1666666666666667      0.0       6.2
# 5     0.0       65    0.76  1.5384615384615385      0.0       8.2
#
#         ...        other_away_elo final_home_elo  final_away_elo  \
# 0       ...           1074.549018     1063.01772     1034.999656
# 1       ...           1074.549018     1063.01772     1034.999656
# 2       ...           1074.549018     1063.01772     1034.999656
# 4       ...           1074.549018     1063.01772     1034.999656
# 5       ...           1074.549018     1063.01772     1034.999656
#
#    home_attack_elo  home_defence_elo  away_attack_elo  away_defence_elo  \
# 0           1.5883          0.991137         1.610078          1.327148
# 1           1.5883          0.991137         1.610078          1.327148
# 2           1.5883          0.991137         1.610078          1.327148
# 4           1.5883          0.991137         1.610078          1.327148
# 5           1.5883          0.991137         1.610078          1.327148
#
#    expected_home_goals  expected_away_goals  calculated_prob
# 0             1.550304             1.349926         7.321279
# 1             1.550304             1.349926        12.363810
# 2             1.550304             1.349926         5.219846
# 4             1.550304             1.349926        12.363810
# 5             1.550304             1.349926         5.219846
#
# [5 rows x 25 columns]

# %%
import decimal
merged.loc[:, 'prob_diff'] = merged[['back_pct_chance', 'calculated_prob']].apply(lambda x: x.calculated_prob - float(x.back_pct_chance), axis=1)
merged.sort_values(by='prob_diff').head(10)
# Out:
#                              event_name score_name_x modified_score_name  \
# 6599      Linfield FC U20 v Ards FC U20        2 - 1               2 - 1
# 8214          Derby U23 v Tottenham U23        1 - 0               1 - 0
# 3754         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 4193  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 18         Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 954            Crusaders v Cliftonville        3 - 2               3 - 2
# 1032           Crusaders v Cliftonville        2 - 2               2 - 2
# 1078           England (W) v Brazil (W)        1 - 0               1 - 0
# 1035           Crusaders v Cliftonville        2 - 2               2 - 2
# 8310               Leeds U23 v Hull U23        2 - 1               2 - 1
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 6599  Any Other Away Win    1.14     1000    0.01  0.10000000000000000000
# 8214               3 - 3     0.0       60    9.38      1.6666666666666667
# 3754               3 - 3   130.0     1000    7.01  0.10000000000000000000
# 4193               3 - 3   610.0     1000    0.67  0.10000000000000000000
# 18                 3 - 3  1000.0     1000    2.05  0.10000000000000000000
# 954                3 - 3    42.0     1000     2.1  0.10000000000000000000
# 1032               3 - 3    42.0     1000     2.1  0.10000000000000000000
# 1078  Any Other Away Win     0.0       50       4      2.0000000000000000
# 1035               0 - 3     0.0      140     7.5  0.71428571428571428571
# 8310  Any Other Away Win    1.14     1000    2.56  0.10000000000000000000
#
#      back_ltp back_odds    ...     final_home_elo final_away_elo  \
# 6599     1.14      1.02    ...        1148.431006     950.281393
# 8214      0.0      1.02    ...        1048.076060    1012.779846
# 3754    130.0      1.02    ...        1091.694938    1075.906810
# 4193    610.0      1.02    ...        1014.262776     994.927916
# 18     1000.0      1.02    ...        1063.017720    1034.999656
# 954     100.0      1.02    ...        1086.338814    1097.515919
# 1032    100.0      1.02    ...        1105.949152    1094.796329
# 1078      0.0      1.02    ...        1086.642611    1000.000000
# 1035      0.0      1.02    ...        1105.949152    1094.796329
# 8310     1.14      1.02    ...        1064.065195     996.883109
#
#       home_attack_elo  home_defence_elo  away_attack_elo  away_defence_elo  \
# 6599         1.734892          1.101166         1.143051          1.409786
# 8214         1.247139          1.167553         1.281022          1.521817
# 3754         1.324826          1.230296         1.205698          1.390246
# 4193         1.474994          1.115403         1.303134          1.178748
# 18           1.588300          0.991137         1.610078          1.327148
# 954          1.745152          1.117792         1.384367          1.104228
# 1032         1.888138          1.100760         1.418916          1.183364
# 1078         1.639516          0.868497         1.182145          1.359675
# 1035         1.888138          1.100760         1.418916          1.183364
# 8310         1.624887          0.983290         1.190829          1.182447
#
#       expected_home_goals  expected_away_goals  calculated_prob  prob_diff
# 6599             1.798831             1.064750         0.836519 -97.202696
# 8214             1.395860             1.265209         0.860175 -97.179041
# 3754             1.354613             1.254808         0.907058 -97.132158
# 4193             1.278722             1.229560         0.935374 -97.103842
# 18               1.550304             1.349926         0.979446 -97.059769
# 954              1.417285             1.309005         1.027358 -97.011858
# 1032             1.643300             1.321230         1.077098 -96.962118
# 1078             1.639516             0.868497         1.174404 -96.864812
# 1035             1.643300             1.321230         1.322237 -96.716978
# 8310             1.413090             0.990512         1.328582 -96.710633
#
# [10 rows x 26 columns]

# %%
import decimal
merged.loc[:, 'prob_diff'] = merged[['back_pct_chance', 'back_prob']].apply(lambda x: x.back_prob - float(x.back_pct_chance), axis=1)
merged.sort_values(by='prob_diff').head(10)
# Out:
#                                            event_name score_name_x  \
# 6599                    Linfield FC U20 v Ards FC U20        2 - 1
# 6526                Larkhall Athletic FC v Cinderford        2 - 3
# 4217                     Sheff Utd U23 v Barnsley U23        1 - 0
# 5627                           Stockport v Altrincham        2 - 0
# 8380                        Sheff Utd U23 v Crewe U23        1 - 2
# 1129                        Curzon Ashton v Southport        1 - 2
# 8328                     Dundee (Res) v Partick (Res)        2 - 2
# 4225  Mansfield Town FC (Res) v Grimsby Town FC (Res)        1 - 0
# 6489                     Crewe U23 v Nottm Forest U23        2 - 1
# 6488                     Crewe U23 v Nottm Forest U23        2 - 1
#
#      modified_score_name        score_name_y lay_ltp lay_odds lay_vol  \
# 6599               2 - 1  Any Other Away Win    1.14     1000    0.01
# 6526               2 - 3  Any Other Away Win    1.14     1000    0.01
# 4217               1 - 0  Any Other Away Win    1.12     1000    0.01
# 5627               2 - 0  Any Other Away Win     0.0       42       4
# 8380               1 - 2  Any Other Away Win    1.14     1000    0.01
# 1129               1 - 2  Any Other Away Win     0.0       34       8
# 8328               2 - 2  Any Other Away Win    1.14     1000    2.56
# 4225               1 - 0  Any Other Away Win    1.12     1000    2.55
# 6489               2 - 1  Any Other Away Win    1.14     1000    2.57
# 6488               2 - 1  Any Other Away Win    1.14     1000    2.57
#
#               lay_pct_chance back_ltp back_odds    ...     final_home_elo  \
# 6599  0.10000000000000000000     1.14      1.02    ...        1148.431006
# 6526  0.10000000000000000000     1.14      1.02    ...        1043.214893
# 4217  0.10000000000000000000     1.12      1.02    ...        1020.733381
# 5627      2.3809523809523810      0.0      1.02    ...        1021.173700
# 8380  0.10000000000000000000     1.14      1.02    ...        1011.053356
# 1129      2.9411764705882353      0.0      1.02    ...         976.854893
# 8328  0.10000000000000000000     1.14      1.02    ...         999.060076
# 4225  0.10000000000000000000     1.12      1.02    ...        1035.740570
# 6489  0.10000000000000000000     1.14      1.02    ...         958.367279
# 6488  0.10000000000000000000     1.14      1.02    ...         958.367279
#
#      final_away_elo  home_attack_elo  home_defence_elo  away_attack_elo  \
# 6599     950.281393         1.734892          1.101166         1.143051
# 6526     923.073987         1.268795          1.047148         1.175954
# 4217     976.915183         1.370701          1.314074         1.099028
# 5627     997.229341         1.261487          1.018973         1.386877
# 8380     977.823148         1.332339          1.252990         1.037923
# 1129     935.875861         1.026830          1.384455         1.113521
# 8328     974.404676         1.447580          1.297710         1.159019
# 4225     972.212399         1.450030          1.208580         1.038861
# 6489     996.489287         1.442019          0.911342         1.542582
# 6488     996.489287         1.442019          0.911342         1.542582
#
#       away_defence_elo  expected_home_goals  expected_away_goals  back_prob  \
# 6599          1.409786             1.798831             1.064750   2.320617
# 6526          1.476203             1.377534             1.041663   2.323821
# 4217          1.753019             1.767234             1.221681   2.374462
# 5627          1.613762             1.497226             1.195446   2.389446
# 8380          1.531472             1.500682             1.100124   2.389516
# 1129          1.648200             1.244724             1.304086   2.411689
# 8328          1.469460             1.564462             1.272323   2.424256
# 4225          1.326175             1.414304             1.062092   2.436379
# 6489          1.349633             1.431369             1.189211   2.450259
# 6488          1.349633             1.431369             1.189211   2.450259
#
#       prob_diff
# 6599 -95.718599
# 6526 -95.715395
# 4217 -95.664754
# 5627 -95.649770
# 8380 -95.649700
# 1129 -95.627527
# 8328 -95.614960
# 4225 -95.602837
# 6489 -95.588956
# 6488 -95.588956
#
# [10 rows x 26 columns]

# %%
merged.columns
# Out:
# Index(['event_name', 'score_name_x', 'modified_score_name', 'score_name_y',
#        'lay_ltp', 'lay_odds', 'lay_vol', 'lay_pct_chance', 'back_ltp',
#        'back_odds', 'back_vol', 'back_pct_chance', 'home_elo', 'away_elo',
#        'other_home_elo', 'other_away_elo', 'final_home_elo', 'final_away_elo',
#        'home_attack_elo', 'home_defence_elo', 'away_attack_elo',
#        'away_defence_elo', 'expected_home_goals', 'expected_away_goals',
#        'calculated_prob', 'prob_diff'],
#       dtype='object')

# %%
def calculate_return(row, stake=1):
    score_name = row.score_name_x
    score_name_guess = row.score_name_y
    if score_name == score_name_guess:
        return stake * row.back_odds
    else:
        return -stake
        
    
merged.loc[:, 'bet_return'] = merged.apply(lambda x: calculate_return(x), axis=1)
merged.sort_values(by='bet_return', ascending=False).head(10)
# Out:
#                           event_name score_name_x modified_score_name  \
# 439    Newport County v Macclesfield        3 - 3               3 - 3
# 533            Aston Villa v Preston        3 - 3               3 - 3
# 1290               Swansea v Ipswich        2 - 3               2 - 3
# 1900          Queen of South v Alloa        3 - 3               3 - 3
# 4659          Doncaster v Gillingham        3 - 3               3 - 3
# 8853    Concord Rangers v Chelmsford        3 - 0               3 - 0
# 2628  Coalville Town v St Neots Town        3 - 3               3 - 3
# 4424      Fulham U23 v West Brom U23        0 - 3               0 - 3
# 2613              Plymouth v Swindon        0 - 3               0 - 3
# 7637      Fleetwood Town v Blackpool        3 - 2               3 - 2
#
#      score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance back_ltp  \
# 439         3 - 3   100.0      120   42.32  0.83333333333333333333    100.0
# 533         3 - 3   110.0      110    1.88  0.90909090909090909091    110.0
# 1290        2 - 3    95.0      110   36.07  0.90909090909090909091     95.0
# 1900        3 - 3     0.0      110    3.52  0.90909090909090909091      0.0
# 4659        3 - 3    90.0       85     2.5      1.1764705882352941     80.0
# 8853        3 - 0     0.0      140    8.58  0.71428571428571428571      0.0
# 2628        3 - 3     0.0      120    3.65  0.83333333333333333333      0.0
# 4424        0 - 3     0.0      120    3.03  0.83333333333333333333      0.0
# 2613        0 - 3     0.0       65   28.72      1.5384615384615385      0.0
# 7637        3 - 2    50.0       60     2.7      1.6666666666666667     50.0
#
#      back_odds     ...     final_away_elo home_attack_elo  home_defence_elo  \
# 439        100     ...         940.411348        1.381157          1.094293
# 533        100     ...        1023.734208        1.676784          1.155422
# 1290        95     ...        1015.751148        1.267285          0.939467
# 1900        75     ...         995.423080        1.221954          1.335217
# 4659        75     ...         961.239140        1.316563          0.998227
# 8853        60     ...        1048.174917        1.378631          0.897893
# 2628        55     ...         952.195128        1.355695          1.136805
# 4424        55     ...         925.718335        1.469745          1.052950
# 2613        55     ...        1012.534759        1.519172          1.165459
# 7637        50     ...        1059.759016        1.290141          1.170805
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 439          1.088558          1.401806             1.423954
# 533          1.390803          1.358432             1.675252
# 1290         1.038131          1.163579             1.084513
# 1900         1.242855          1.208485             1.086078
# 4659         1.274330          1.262142             1.222122
# 8853         1.255764          1.039675             1.054169
# 2628         0.943471          1.360492             1.356510
# 4424         0.880102          1.693672             1.830780
# 2613         1.315485          1.356825             1.515987
# 7637         1.027665          0.958577             0.909556
#
#       expected_away_goals  calculated_prob  prob_diff  bet_return
# 439              1.007661         0.767781  -0.232219         100
# 533              1.359363         1.082239   0.082239         100
# 1290             0.825017         1.188856   0.136225          95
# 1900             1.403788         0.858692  -0.474641          75
# 4659             1.076069         0.723072  -0.610262          75
# 8853             0.953810         3.251492   1.584825          60
# 2628             0.907285         0.847994  -0.970188          55
# 4424             0.783916         1.481156  -0.337026          55
# 2613             1.296917         2.814740   0.996558          55
# 7637             1.017806         1.660159  -0.339841          50
#
# [10 rows x 27 columns]

# %%
def calculate_return(row, stake=1):
    score_name = row.modified_score_name
    score_name_guess = row.score_name_y
    if score_name == score_name_guess:
        return stake * row.back_odds
    else:
        return -stake
        
    
merged.loc[:, 'bet_return'] = merged.apply(lambda x: calculate_return(x), axis=1)
merged.sort_values(by='bet_return', ascending=False).head(10)
# Out:
#                           event_name score_name_x modified_score_name  \
# 439    Newport County v Macclesfield        3 - 3               3 - 3
# 533            Aston Villa v Preston        3 - 3               3 - 3
# 1290               Swansea v Ipswich        2 - 3               2 - 3
# 1900          Queen of South v Alloa        3 - 3               3 - 3
# 4659          Doncaster v Gillingham        3 - 3               3 - 3
# 8853    Concord Rangers v Chelmsford        3 - 0               3 - 0
# 4424      Fulham U23 v West Brom U23        0 - 3               0 - 3
# 2628  Coalville Town v St Neots Town        3 - 3               3 - 3
# 2613              Plymouth v Swindon        0 - 3               0 - 3
# 7637      Fleetwood Town v Blackpool        3 - 2               3 - 2
#
#      score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance back_ltp  \
# 439         3 - 3   100.0      120   42.32  0.83333333333333333333    100.0
# 533         3 - 3   110.0      110    1.88  0.90909090909090909091    110.0
# 1290        2 - 3    95.0      110   36.07  0.90909090909090909091     95.0
# 1900        3 - 3     0.0      110    3.52  0.90909090909090909091      0.0
# 4659        3 - 3    90.0       85     2.5      1.1764705882352941     80.0
# 8853        3 - 0     0.0      140    8.58  0.71428571428571428571      0.0
# 4424        0 - 3     0.0      120    3.03  0.83333333333333333333      0.0
# 2628        3 - 3     0.0      120    3.65  0.83333333333333333333      0.0
# 2613        0 - 3     0.0       65   28.72      1.5384615384615385      0.0
# 7637        3 - 2    50.0       60     2.7      1.6666666666666667     50.0
#
#      back_odds     ...     final_away_elo home_attack_elo  home_defence_elo  \
# 439        100     ...         940.411348        1.381157          1.094293
# 533        100     ...        1023.734208        1.676784          1.155422
# 1290        95     ...        1015.751148        1.267285          0.939467
# 1900        75     ...         995.423080        1.221954          1.335217
# 4659        75     ...         961.239140        1.316563          0.998227
# 8853        60     ...        1048.174917        1.378631          0.897893
# 4424        55     ...         925.718335        1.469745          1.052950
# 2628        55     ...         952.195128        1.355695          1.136805
# 2613        55     ...        1012.534759        1.519172          1.165459
# 7637        50     ...        1059.759016        1.290141          1.170805
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 439          1.088558          1.401806             1.423954
# 533          1.390803          1.358432             1.675252
# 1290         1.038131          1.163579             1.084513
# 1900         1.242855          1.208485             1.086078
# 4659         1.274330          1.262142             1.222122
# 8853         1.255764          1.039675             1.054169
# 4424         0.880102          1.693672             1.830780
# 2628         0.943471          1.360492             1.356510
# 2613         1.315485          1.356825             1.515987
# 7637         1.027665          0.958577             0.909556
#
#       expected_away_goals  back_prob  prob_diff  bet_return
# 439              1.007661   2.785695   1.785695         100
# 533              1.359363   2.759967   1.759967         100
# 1290             0.825017   2.680481   1.627849          95
# 1900             1.403788   3.367659   2.034325          75
# 4659             1.076069   2.954868   1.621535          75
# 8853             0.953810   3.757627   2.090960          60
# 4424             0.783916   3.827367   2.009186          55
# 2628             0.907285   2.520702   0.702520          55
# 2613             1.296917   4.111777   2.293595          55
# 7637             1.017806   3.830846   1.830846          50
#
# [10 rows x 27 columns]

# %%
merged[merged.bet_return > 0].shape
# Out:
# (494, 27)

# %%
merged.sort_values(by='prob_diff').head(10)
# Out:
#                              event_name score_name_x modified_score_name  \
# 6599      Linfield FC U20 v Ards FC U20        2 - 1               2 - 1
# 8214          Derby U23 v Tottenham U23        1 - 0               1 - 0
# 3754         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 4193  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 18         Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 954            Crusaders v Cliftonville        3 - 2               3 - 2
# 1032           Crusaders v Cliftonville        2 - 2               2 - 2
# 1078           England (W) v Brazil (W)        1 - 0               1 - 0
# 1035           Crusaders v Cliftonville        2 - 2               2 - 2
# 8310               Leeds U23 v Hull U23        2 - 1               2 - 1
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 6599  Any Other Away Win    1.14     1000    0.01  0.10000000000000000000
# 8214               3 - 3     0.0       60    9.38      1.6666666666666667
# 3754               3 - 3   130.0     1000    7.01  0.10000000000000000000
# 4193               3 - 3   610.0     1000    0.67  0.10000000000000000000
# 18                 3 - 3  1000.0     1000    2.05  0.10000000000000000000
# 954                3 - 3    42.0     1000     2.1  0.10000000000000000000
# 1032               3 - 3    42.0     1000     2.1  0.10000000000000000000
# 1078  Any Other Away Win     0.0       50       4      2.0000000000000000
# 1035               0 - 3     0.0      140     7.5  0.71428571428571428571
# 8310  Any Other Away Win    1.14     1000    2.56  0.10000000000000000000
#
#      back_ltp back_odds     ...     final_away_elo home_attack_elo  \
# 6599     1.14      1.02     ...         950.281393        1.734892
# 8214      0.0      1.02     ...        1012.779846        1.247139
# 3754    130.0      1.02     ...        1075.906810        1.324826
# 4193    610.0      1.02     ...         994.927916        1.474994
# 18     1000.0      1.02     ...        1034.999656        1.588300
# 954     100.0      1.02     ...        1097.515919        1.745152
# 1032    100.0      1.02     ...        1094.796329        1.888138
# 1078      0.0      1.02     ...        1000.000000        1.639516
# 1035      0.0      1.02     ...        1094.796329        1.888138
# 8310     1.14      1.02     ...         996.883109        1.624887
#
#       home_defence_elo  away_attack_elo  away_defence_elo  \
# 6599          1.101166         1.143051          1.409786
# 8214          1.167553         1.281022          1.521817
# 3754          1.230296         1.205698          1.390246
# 4193          1.115403         1.303134          1.178748
# 18            0.991137         1.610078          1.327148
# 954           1.117792         1.384367          1.104228
# 1032          1.100760         1.418916          1.183364
# 1078          0.868497         1.182145          1.359675
# 1035          1.100760         1.418916          1.183364
# 8310          0.983290         1.190829          1.182447
#
#       expected_home_goals  expected_away_goals  calculated_prob  prob_diff  \
# 6599             1.798831             1.064750         0.836519 -97.202696
# 8214             1.395860             1.265209         0.860175 -97.179041
# 3754             1.354613             1.254808         0.907058 -97.132158
# 4193             1.278722             1.229560         0.935374 -97.103842
# 18               1.550304             1.349926         0.979446 -97.059769
# 954              1.417285             1.309005         1.027358 -97.011858
# 1032             1.643300             1.321230         1.077098 -96.962118
# 1078             1.639516             0.868497         1.174404 -96.864812
# 1035             1.643300             1.321230         1.322237 -96.716978
# 8310             1.413090             0.990512         1.328582 -96.710633
#
#       bet_return
# 6599          -1
# 8214          -1
# 3754          -1
# 4193          -1
# 18            -1
# 954           -1
# 1032          -1
# 1078          -1
# 1035          -1
# 8310          -1
#
# [10 rows x 27 columns]

# %%
merged[merged.prob_diff > 2].bet_return.sum()
# Out:
# Decimal('71.3')

# %%
merged[merged.prob_diff < 2].bet_return.sum()
# Out:
# Decimal('-1032.64')

# %%
t = np.linspace(-5, 5, 100)
def pct_returns(val, frame):
    return frame[frame.prob_diff > val].bet_return.sum() / frame[frame.prob_diff > val].shape[0]

def other_pct_returns(val, frame):
    return frame[frame.pct_back_difference > val].bet_return.sum() / frame[frame.pct_back_difference > val].shape[0]

return_strategy = [100.*float(pct_returns(l, merged)) for l in t]
return_strategy[0]
# Out:
# -7.5991673412744305

# %%
fig, ax = plt.subplots(figsize=(20,12))
plt.plot(t, return_strategy)
ax.axhline(y=0, color='k', ls=':')
plt.xlabel('Percentage edge', fontsize=18)
plt.xticks(fontsize=18)
plt.ylabel('Percentage returns', fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
merged[merged.prob_diff > 0.5].bet_return.sum()
# Out:
# Decimal('72.9')

# %%
merged.loc[:, 'lay_prob_diff'] = merged.apply(lambda x: float(x.lay_pct_chance) - x.calculated_prob, axis=1)
merged.sort_values(by='lay_prob_diff').head()
# Out:
#                          event_name score_name_x modified_score_name  \
# 839           Tottenham v Barcelona        2 - 4  Any Other Away Win
# 74          Burnley U23 v Crewe U23        3 - 2               3 - 2
# 5764  The New Saints v Connahs Quay        3 - 0               3 - 0
# 3744     Leyton Orient v Hartlepool        0 - 0               0 - 0
# 8453  Millwall U23 v Colchester U23        2 - 3               2 - 3
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 839   Any Other Home Win    30.0       30   68.09      3.3333333333333333
# 74                 1 - 1     0.0      650       2  0.15384615384615384615
# 5764               0 - 1     0.0       60       2      1.6666666666666667
# 3744               1 - 1    24.0      140   62.44  0.71428571428571428571
# 8453               1 - 0     0.0       40       4      2.5000000000000000
#
#      back_ltp back_odds      ...       home_attack_elo home_defence_elo  \
# 839      29.0        27      ...              2.520367         0.785386
# 74        0.0       6.2      ...              1.448086         1.252371
# 5764      0.0        24      ...              1.641913         0.865326
# 3744     30.0        50      ...              1.324826         1.230296
# 8453      0.0       5.8      ...              1.437460         0.943744
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 839          1.172790          1.478477             2.740584
# 74           1.045378          1.485576             1.582174
# 5764         1.197274          0.890084             1.074846
# 3744         1.205698          1.390246             1.354613
# 8453         0.977884          1.688381             1.784971
#
#       expected_away_goals  calculated_prob  prob_diff  bet_return  \
# 839              0.779170        21.313706  17.610002          -1
# 74               1.107479        12.312376  -3.816656          -1
# 5764             0.876400        13.753076   9.586409          -1
# 3744             1.254808        12.534824  10.534824          -1
# 8453             0.780676        13.188519  -4.052860          -1
#
#       lay_prob_diff
# 839      -17.980372
# 74       -12.158530
# 5764     -12.086409
# 3744     -11.820538
# 8453     -10.688519
#
# [5 rows x 28 columns]

# %%
merged.sort_values(by='lay_prob_diff', ascending=False).head()
# Out:
#                              event_name score_name_x modified_score_name  \
# 96                  Hendon v Lancing FC        1 - 1               1 - 1
# 10         Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 4184  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 3742         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 1026           Crusaders v Cliftonville        2 - 2               2 - 2
#
#      score_name_y lay_ltp lay_odds lay_vol       lay_pct_chance back_ltp  \
# 96          0 - 0    1.03     1.03    3.03  97.0873786407766990     1.03
# 10          2 - 0    1.13     1.08       3  92.5925925925925926     1.13
# 4184        0 - 1    1.11     1.09    3.07  91.7431192660550459     1.11
# 3742        0 - 0    1.26     1.11   41.81  90.0900900900900901     1.26
# 1026        2 - 2     1.2      1.2    5.94  83.3333333333333333      1.2
#
#      back_odds      ...       home_attack_elo home_defence_elo  \
# 96          24      ...              1.722344         1.187936
# 10        1.02      ...              1.588300         0.991137
# 4184      1.03      ...              1.474994         1.115403
# 3742      1.02      ...              1.324826         1.230296
# 1026      1.02      ...              1.888138         1.100760
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 96           1.182145          1.359675             1.722344
# 10           1.610078          1.327148             1.550304
# 4184         1.303134          1.178748             1.278722
# 3742         1.205698          1.390246             1.354613
# 1026         1.418916          1.183364             1.643300
#
#       expected_away_goals  calculated_prob  prob_diff  bet_return  \
# 96               1.187936         6.285098   2.118431          -1
# 10               1.349926         7.690810 -90.348406        1.02
# 4184             1.229560         8.562812 -88.524567        1.03
# 3742             1.254808         7.766201 -90.273015        1.02
# 1026             1.321230         5.256839 -92.782377        1.02
#
#       lay_prob_diff
# 96        90.802281
# 10        84.901783
# 4184      83.180307
# 3742      82.323890
# 1026      78.076494
#
# [5 rows x 28 columns]

# %%
def calculate_return_lay(row, stake=1):
    score_name = row.modified_score_name
    score_name_guess = row.score_name_y
    if score_name == score_name_guess:
        return -stake * row.lay_odds
    else:
        return stake

# %%
merged.loc[:, 'lay_return'] = merged.apply(lambda x: calculate_return_lay(x), axis=1)
merged.sort_values(by='lay_return', ascending=False).head(10)
# Out:
#                         event_name score_name_x modified_score_name  \
# 0     Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 6102            MK Dons v Notts Co        2 - 1               2 - 1
# 6096           Oldham v Cheltenham        2 - 0               2 - 0
# 6097           Oldham v Cheltenham        2 - 0               2 - 0
# 6098           Oldham v Cheltenham        2 - 0               2 - 0
# 6099           Oldham v Cheltenham        2 - 0               2 - 0
# 6100            MK Dons v Notts Co        2 - 1               2 - 1
# 6101            MK Dons v Notts Co        2 - 1               2 - 1
# 6103            MK Dons v Notts Co        2 - 1               2 - 1
# 6076      Wrexham v Harrogate Town        2 - 0               2 - 0
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 0                  0 - 0     0.0       65    0.76      1.5384615384615385
# 6102               1 - 1     9.8       10   89.96     10.0000000000000000
# 6096               1 - 3     0.0       75   70.45      1.3333333333333333
# 6097               0 - 3     0.0      120   10.78  0.83333333333333333333
# 6098  Any Other Home Win    15.5     15.5   15.04      6.4516129032258065
# 6099  Any Other Away Win     0.0      690   80.22  0.14492753623188405797
# 6100               0 - 0    19.0       19   42.37      5.2631578947368421
# 6101               1 - 0     9.6      9.8      19     10.2040816326530612
# 6103               0 - 1     0.0       24   28.08      4.1666666666666667
# 6076               3 - 3     0.0      180    2.62  0.55555555555555555556
#
#      back_ltp back_odds     ...     home_defence_elo away_attack_elo  \
# 0        12.0      12.5     ...             0.991137        1.610078
# 6102      9.8       9.4     ...             0.959237        1.178821
# 6096      0.0        60     ...             1.528445        1.159660
# 6097      0.0        95     ...             1.528445        1.159660
# 6098     15.5        14     ...             1.528445        1.159660
# 6099      0.0        65     ...             1.528445        1.159660
# 6100     17.5      17.5     ...             0.959237        1.178821
# 6101      9.6       9.4     ...             0.959237        1.178821
# 6103      0.0        21     ...             0.959237        1.178821
# 6076      0.0        75     ...             0.764043        1.435068
#
#       away_defence_elo  expected_home_goals  expected_away_goals  \
# 0             1.327148             1.550304             1.349926
# 6102          1.622874             1.422015             0.956539
# 6096          1.587526             1.353769             1.499372
# 6097          1.587526             1.353769             1.499372
# 6098          1.587526             1.353769             1.499372
# 6099          1.587526             1.353769             1.499372
# 6100          1.622874             1.422015             0.956539
# 6101          1.622874             1.422015             0.956539
# 6103          1.622874             1.422015             0.956539
# 6076          1.176991             1.161104             0.927511
#
#       calculated_prob  prob_diff  bet_return  lay_prob_diff  lay_return
# 0            7.321279  -0.678721          -1      -5.782817           1
# 6102        12.309608   1.671310          -1      -2.309608           1
# 6096         2.642702   0.976035          -1      -1.309368           1
# 6097         1.881671   0.829040          -1      -1.048338           1
# 6098         5.296722  -1.846135          -1       1.154890           1
# 6099         2.612681   1.074220          -1      -2.467754           1
# 6100         9.136701   3.422415          -1      -3.873543           1
# 6101        13.586350   2.948052          -1      -3.382268           1
# 6103         8.278104   3.516199          -1      -4.111437           1
# 6076         0.488450  -0.844883          -1       0.067105           1
#
# [10 rows x 29 columns]

# %%
merged.sort_values(by='lay_return', ascending=True).head(10)
# Out:
#                           event_name score_name_x modified_score_name  \
# 8853    Concord Rangers v Chelmsford        3 - 0               3 - 0
# 7980         Hartlepool v Sutton Utd        2 - 3               2 - 3
# 2628  Coalville Town v St Neots Town        3 - 3               3 - 3
# 439    Newport County v Macclesfield        3 - 3               3 - 3
# 4424      Fulham U23 v West Brom U23        0 - 3               0 - 3
# 1900          Queen of South v Alloa        3 - 3               3 - 3
# 1290               Swansea v Ipswich        2 - 3               2 - 3
# 533            Aston Villa v Preston        3 - 3               3 - 3
# 5841      Charlton U23 v Ipswich U23        2 - 2               2 - 2
# 4659          Doncaster v Gillingham        3 - 3               3 - 3
#
#      score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance back_ltp  \
# 8853        3 - 0     0.0      140    8.58  0.71428571428571428571      0.0
# 7980        2 - 3     0.0      130    0.39  0.76923076923076923077      0.0
# 2628        3 - 3     0.0      120    3.65  0.83333333333333333333      0.0
# 439         3 - 3   100.0      120   42.32  0.83333333333333333333    100.0
# 4424        0 - 3     0.0      120    3.03  0.83333333333333333333      0.0
# 1900        3 - 3     0.0      110    3.52  0.90909090909090909091      0.0
# 1290        2 - 3    95.0      110   36.07  0.90909090909090909091     95.0
# 533         3 - 3   110.0      110    1.88  0.90909090909090909091    110.0
# 5841        2 - 2     0.0       90    3.82      1.1111111111111111      0.0
# 4659        3 - 3    90.0       85     2.5      1.1764705882352941     80.0
#
#      back_odds     ...     home_defence_elo away_attack_elo  away_defence_elo  \
# 8853        60     ...             0.897893        1.255764          1.039675
# 7980        32     ...             1.077560        1.224036          1.104546
# 2628        55     ...             1.136805        0.943471          1.360492
# 439        100     ...             1.094293        1.088558          1.401806
# 4424        55     ...             1.052950        0.880102          1.693672
# 1900        75     ...             1.335217        1.242855          1.208485
# 1290        95     ...             0.939467        1.038131          1.163579
# 533        100     ...             1.155422        1.390803          1.358432
# 5841       8.8     ...             0.885755        1.279599          1.264736
# 4659        75     ...             0.998227        1.274330          1.262142
#
#       expected_home_goals  expected_away_goals  calculated_prob  prob_diff  \
# 8853             1.054169             0.953810         3.251492   1.584825
# 7980             0.832765             1.115745         1.682216  -1.442784
# 2628             1.356510             0.907285         0.847994  -0.970188
# 439              1.423954             1.007661         0.767781  -0.232219
# 4424             1.830780             0.783916         1.481156  -0.337026
# 1900             1.086078             1.403788         0.858692  -0.474641
# 1290             1.084513             0.825017         1.188856   0.136225
# 533              1.675252             1.359363         1.082239   0.082239
# 5841             1.383846             0.958775         5.095900  -6.267737
# 4659             1.222122             1.076069         0.723072  -0.610262
#
#       bet_return  lay_prob_diff  lay_return
# 8853          60      -2.537206        -140
# 7980          32      -0.912985        -130
# 2628          55      -0.014661        -120
# 439          100       0.065552        -120
# 4424          55      -0.647822        -120
# 1900          75       0.050399        -110
# 1290          95      -0.279766        -110
# 533          100      -0.173148        -110
# 5841         8.8      -3.984789         -90
# 4659          75       0.453399         -85
#
# [10 rows x 29 columns]

# %%
merged.bet_return.sum()
# Out:
# Decimal('-961.34')

# %%
merged.lay_return.sum()
# Out:
# Decimal('-1288.34')

# %%
merged[merged.lay_prob_diff > 2].lay_return.sum()
# Out:
# Decimal('110.16')

# %%
merged[merged.lay_prob_diff < -2].lay_return.sum()
# Out:
# Decimal('-701.5')

# %%
merged.lay_prob_diff.describe()
# Out:
# count    9056.000000
# mean       -0.462244
# std         3.404978
# min       -17.980372
# 25%        -1.537105
# 50%        -0.309928
# 75%         0.542614
# max        90.802281
# Name: lay_prob_diff, dtype: float64

# %%
def lay_pct_returns(val, frame):
    return frame[frame.lay_prob_diff > val].lay_return.sum() / frame[frame.prob_diff > val].shape[0]

t = np.linspace(-3, 3, 200)
return_strategy = [100.*float(pct_returns(l, merged)) for l in t]
return_strategy[0]
# Out:
# -5.645417839226722

# %%
fig, ax = plt.subplots(figsize=(20,12))
plt.plot(t, return_strategy)
ax.axhline(y=0, color='k', ls=':')
plt.xlabel('Percentage edge', fontsize=18)
plt.xticks(fontsize=18)
plt.ylabel('Percentage returns', fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
merged[merged.lay_prob_diff > 1.5].lay_return.sum()
# Out:
# Decimal('87.06')

# %%
100.0*float((
    merged[merged.lay_prob_diff >= 1].lay_return.sum() 
    + merged[merged.prob_diff >= 1].bet_return.sum()
)/(
    merged[merged.lay_prob_diff >= 1].shape[0]
    + merged[merged.prob_diff >= 1].shape[0]
))
# Out:
# 8.319338422391857

# %%
merged[merged.lay_prob_diff >= 1].lay_return.sum() + merged[merged.prob_diff >= 1].bet_return.sum()
# Out:
# Decimal('261.56')
