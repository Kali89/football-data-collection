# %%
import psycopg2
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /usr/local/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
conn = psycopg2.connect("dbname=football")
cur = conn.cursor()

sql = """
WITH markets AS (
    SELECT
        event_name,
        event_id,
        open_date,
        mc_id
    FROM
        market_changes
    GROUP BY
        event_name,
        event_id,
        open_date,
        mc_id
)

SELECT
mc.event_name,
mc.event_id,
mc.open_date,
min(r.name) AS score_name
FROM
runners r
INNER JOIN
markets mc
ON mc.mc_id = r.mc_id
WHERE r.status = 'WINNER'
GROUP BY
mc.event_name,
mc.event_id,
mc.open_date
ORDER BY
mc.event_id
"""

cur.execute(sql)

results = cur.fetchall()
colnames = [desc[0] for desc in cur.description]
conn.close()

# %%
df = pd.DataFrame(results, columns=colnames)
df.head()
# Out:
#              event_name  event_id           open_date score_name
# 0                 T v A  27041861 2013-07-29 10:14:25      0 - 0
# 1           New v Cat 5  27041907 2013-07-29 11:44:42      1 - 0
# 2        Test v Subject  27144881 2015-12-14 12:34:00      1 - 0
# 3        Test v Subject  27144881 2020-02-06 11:30:00      1 - 0
# 4  Tottenham v Man City  27425811 2015-05-03 15:00:00      0 - 1

# %%
df.shape
# Out:
# (25036, 4)

# %% [markdown]
# ### Creating results

# %%
df.loc[:, 'home_team'] = df.event_name.apply(lambda x: x.split(' v ')[0])
df.loc[:, 'away_team'] = df.event_name.apply(lambda x: x.split(' v ')[-1])
df = df[(df.open_date >= '2015-04-01') & (df.open_date < '2019-01-01')].sort_values(by='open_date')
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team
# 6                1 - 3               Leicester            Chelsea
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic
# 17               5 - 0                  Celtic             Dundee
# 59               1 - 2            Nottm Forest            Cardiff
# 58               4 - 2                 Norwich             Fulham

# %% [markdown]
# ## ELO

# %%
HISTORY = 10
k_factor = 32
elo_width = 400.

def calculate_new_elos(rating_a, rating_b, score_a, k_factor, elo_width):
    """Calculates and returns the new Elo ratings for two players.
    score_a is 1 for a win by player A, 0 for a loss by player A, or 0.5 for a draw.
    """

    e_a = expected_result(rating_a, rating_b, elo_width)
    e_b = 1. - e_a
    new_rating_a = rating_a + k_factor * (score_a - e_a)
    score_b = 1. - score_a
    new_rating_b = rating_b + k_factor * (score_b - e_b)
    return new_rating_a, new_rating_b
    

def expected_result(elo_a, elo_b, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expect_a = 1.0/(1+10**((elo_b - elo_a)/elo_width))
    return expect_a


def update_end_of_season(elos):
    """Regression towards the mean
    
    Following 538 nfl methods
    https://fivethirtyeight.com/datalab/nfl-elo-ratings-are-back/
    """
    diff_from_mean = elos - np.mean(elos)
    elos -= diff_from_mean/3
    return elos

# %%
def create_team_frame(frame, elo=1000):
    teams = pd.DataFrame(pd.unique(frame[['home_team', 'away_team']].values.ravel('K')), columns=['team'])   
    teams.loc[:, 'elo']  = elo
    return teams

def calculate_numeric_result(entry):
    home_goal = int(entry.split(' - ')[0])
    away_goal = int(entry.split(' - ')[1])
    if home_goal > away_goal:
        return 1
    elif home_goal == away_goal:
        return 0.5
    else:
        return 0

def calculate_result(row):
    result = row.score_name
    if result == 'Any Other Home Win':
        return 1
    elif result == 'Any Other Away Win':
        return 0
    elif result == 'Any Other Draw':
        return 0.5
    elif result == 'Any unquoted':
        return 0.5
    else:
        return calculate_numeric_result(result)

# %%
df.loc[:, 'home_elo'] = 1000.
df.loc[:, 'away_elo'] = 1000.
season_frame = create_team_frame(df)
for index, row in df.iterrows():
    home = row.home_team
    away = row.away_team
    home_elo = season_frame[season_frame.team == home].elo.values[0]
    away_elo = season_frame[season_frame.team == away].elo.values[0]
    df.loc[df.event_id == row.event_id, 'home_elo'] = home_elo
    df.loc[df.event_id == row.event_id, 'away_elo'] = away_elo
    expected_results = expected_result(home_elo, away_elo, elo_width)
    result = calculate_result(row)
    new_home_elo, new_away_elo = calculate_new_elos(home_elo, away_elo, result, k_factor, elo_width)
    season_frame.loc[season_frame.team == home, 'elo'] = new_home_elo
    season_frame.loc[season_frame.team == away, 'elo'] = new_away_elo

# %%
df[['event_name', 'event_id', 'open_date']].drop_duplicates().shape
# Out:
# (25031, 3)

# %%
df.sort_values(by='home_elo').head()
# Out:
#                            event_name  event_id           open_date  \
# 19268  North Ferriby Utd v Boston Utd  28543909 2018-01-20 15:00:00
# 19923   North Ferriby Utd v Southport  28581212 2018-02-17 15:00:00
# 19566  North Ferriby Utd v Leamington  28560969 2018-02-03 15:00:00
# 20158         Cowdenbeath v Peterhead  28591974 2018-02-24 15:00:00
# 20574             Cowdenbeath v Elgin  28624513 2018-03-17 15:00:00
#
#                score_name          home_team   away_team    home_elo  \
# 19268  Any Other Away Win  North Ferriby Utd  Boston Utd  741.818654
# 19923               0 - 3  North Ferriby Utd   Southport  743.758148
# 19566               1 - 1  North Ferriby Utd  Leamington  746.933582
# 20158               0 - 2        Cowdenbeath   Peterhead  751.852184
# 20574               3 - 1        Cowdenbeath       Elgin  752.345995
#
#           away_elo
# 19268   985.533270
# 19923   939.237792
# 19566   990.294107
# 20158  1016.885075
# 20574   939.729064

# %%
df.sort_values(by='home_elo', ascending=False).head()
# Out:
#                     event_name  event_id           open_date  \
# 22228  Man City v Huddersfield  28824829 2018-08-19 12:30:00
# 15014            Celtic v Lyon  28306512 2017-07-15 14:00:00
# 23248          Man City v Lyon  28880548 2018-09-19 19:00:00
# 22887     Man City v Newcastle  28854367 2018-09-01 16:30:00
# 24651      Man City v Shakhtar  28974151 2018-11-07 20:00:00
#
#                score_name home_team     away_team     home_elo     away_elo
# 22228               6 - 1  Man City  Huddersfield  1410.163957  1069.134611
# 15014  Any Other Away Win    Celtic          Lyon  1409.009169   971.443550
# 23248               1 - 2  Man City          Lyon  1407.409590  1026.732961
# 22887               2 - 1  Man City     Newcastle  1403.098891  1079.993199
# 24651               6 - 0  Man City      Shakhtar  1401.287688   995.202096

# %%
df.loc[:, 'home_team_goal'] = df.score_name.apply(lambda x: int(x.split(' - ')[0]) if len(x.split(' - ')) > 1 else None)
df.loc[:, 'away_team_goal'] = df.score_name.apply(lambda x: int(x.split(' - ')[1]) if len(x.split(' - ')) > 1 else None)
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  home_team_goal  away_team_goal
# 6     1000.0             1.0             3.0
# 93    1000.0             NaN             NaN
# 17    1000.0             5.0             0.0
# 59    1000.0             1.0             2.0
# 58    1000.0             4.0             2.0

# %%
HOME_TEAM_BASE = np.mean(df.home_team_goal)
AWAY_TEAM_BASE = np.mean(df.away_team_goal)

k_factor = 32
score_k_factor = 0.05

def calculate_new_elos_score(rating_a, rating_b, score_a, home, k_factor):
    """Calculates and returns the new Elo ratings for two players.
    score_a is 1 for a win by player A, 0 for a loss by player A, or 0.5 for a draw.
    """
    if home:
        e_a = expected_result_score(rating_a, rating_b, HOME_TEAM_BASE)
    else:
        e_a = expected_result_score(rating_a, rating_b, AWAY_TEAM_BASE)
    new_rating_a = rating_a + (k_factor * (score_a - e_a))
    new_rating_b = rating_b + (k_factor * (score_a - e_a))
    return new_rating_a, new_rating_b
    

def expected_result_score(elo_a, elo_b, base):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expect_a = (elo_a/base) * (elo_b/base) * base
    return expect_a


def update_end_of_season(elos):
    """Regression towards the mean
    
    Following 538 nfl methods
    https://fivethirtyeight.com/datalab/nfl-elo-ratings-are-back/
    """
    diff_from_mean = elos - np.mean(elos)
    elos -= diff_from_mean/3
    return elos

# %%
def get_elos(frame, names):
    return [frame[frame.team == entry].elo.values[0] for entry in names]

df.loc[:, 'home_elo'] = 1000.
df.loc[:, 'away_elo'] = 1000.
df.loc[:, 'home_attack_elo'] = HOME_TEAM_BASE
df.loc[:, 'home_defence_elo'] = AWAY_TEAM_BASE
df.loc[:, 'away_attack_elo'] = AWAY_TEAM_BASE
df.loc[:, 'away_defence_elo'] = HOME_TEAM_BASE


season_frame = create_team_frame(df)
home_attack_frame = create_team_frame(df, HOME_TEAM_BASE)
home_defence_frame = create_team_frame(df, AWAY_TEAM_BASE)
away_attack_frame = create_team_frame(df, AWAY_TEAM_BASE)
away_defence_frame = create_team_frame(df, HOME_TEAM_BASE)

i = 0

for index, row in df.iterrows():
    if i % 1000 == 0:
        print(i)
    i += 1
    home = row.home_team
    away = row.away_team
    home_team_goals = row.home_team_goal
    away_team_goals = row.away_team_goal
    
    home_elo, away_elo = get_elos(season_frame, (home, away))
    home_attack_elo = get_elos(home_attack_frame, (home,))[0]
    home_defence_elo = get_elos(home_defence_frame, (home,))[0]
    away_attack_elo = get_elos(away_attack_frame, (away,))[0]
    away_defence_elo = get_elos(away_defence_frame, (away,))[0]
        
    df.loc[df.event_id == row.event_id, 'home_elo'] = home_elo
    df.loc[df.event_id == row.event_id, 'away_elo'] = away_elo
    df.loc[df.event_id == row.event_id, 'home_attack_elo'] = home_attack_elo
    df.loc[df.event_id == row.event_id, 'away_attack_elo'] = away_attack_elo
    df.loc[df.event_id == row.event_id, 'home_defence_elo'] = home_defence_elo
    df.loc[df.event_id == row.event_id, 'away_defence_elo'] = away_defence_elo  
        
    expected_results = expected_result(home_elo, away_elo, elo_width)
    result = calculate_result(row)
    new_home_elo, new_away_elo = calculate_new_elos(home_elo, away_elo, result, k_factor, elo_width)
    season_frame.loc[season_frame.team == home, 'elo'] = new_home_elo
    season_frame.loc[season_frame.team == away, 'elo'] = new_away_elo  
    
    if (not pd.isna(home_team_goals)) and (not pd.isna(away_team_goals)):
        new_home_attack_elo, new_away_defence_elo = calculate_new_elos_score(home_attack_elo, away_defence_elo, home_team_goals, True, score_k_factor)
        new_away_attack_elo, new_home_defence_elo = calculate_new_elos_score(away_attack_elo, home_defence_elo, away_team_goals, False, score_k_factor)        
        home_attack_frame.loc[home_attack_frame.team == home, 'elo'] = new_home_attack_elo
        home_defence_frame.loc[home_defence_frame.team == home, 'elo'] = new_home_defence_elo
        away_attack_frame.loc[away_attack_frame.team == away, 'elo'] = new_away_attack_elo
        away_defence_frame.loc[away_defence_frame.team == away, 'elo'] = new_away_defence_elo
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000

# %%
home_attack_frame[pd.isnull(home_attack_frame.elo)]
# Out:
# Empty DataFrame
# Columns: [team, elo]
# Index: []

# %%
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  home_team_goal  away_team_goal  home_attack_elo  \
# 6     1000.0             1.0             3.0         1.359675
# 93    1000.0             NaN             NaN         1.359675
# 17    1000.0             5.0             0.0         1.359675
# 59    1000.0             1.0             2.0         1.359675
# 58    1000.0             4.0             2.0         1.359675
#
#     home_defence_elo  away_attack_elo  away_defence_elo
# 6           1.182145         1.182145          1.359675
# 93          1.182145         1.182145          1.359675
# 17          1.182145         1.182145          1.359675
# 59          1.182145         1.182145          1.359675
# 58          1.182145         1.182145          1.359675

# %%
df.sort_values(by='home_attack_elo', ascending=False).head()
# Out:
#                  event_name  event_id           open_date score_name  \
# 24651   Man City v Shakhtar  28974151 2018-11-07 20:00:00      6 - 0
# 22887  Man City v Newcastle  28854367 2018-09-01 16:30:00      2 - 1
# 23248       Man City v Lyon  28880548 2018-09-19 19:00:00      1 - 2
# 24296     Man City v Fulham  28949910 2018-11-01 19:45:00      2 - 0
# 20012    Man City v Chelsea  28585883 2018-03-04 16:00:00      1 - 0
#
#       home_team  away_team     home_elo     away_elo  home_team_goal  \
# 24651  Man City   Shakhtar  1401.287688   995.202096             6.0
# 22887  Man City  Newcastle  1403.098891  1079.993199             2.0
# 23248  Man City       Lyon  1407.409590  1026.732961             1.0
# 24296  Man City     Fulham  1390.967119  1126.327694             2.0
# 20012  Man City    Chelsea  1373.156640  1239.511180             1.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 24651             0.0         3.029895          0.683013         1.141061
# 22887             1.0         2.921392          0.720163         1.267457
# 23248             2.0         2.892597          0.731556         1.120381
# 24296             0.0         2.882054          0.720138         1.680823
# 20012             0.0         2.879443          0.658609         1.936112
#
#        away_defence_elo
# 24651          1.340753
# 22887          1.198873
# 23248          1.382396
# 24296          1.475655
# 20012          0.855453

# %%
df.sort_values(by='away_attack_elo', ascending=False).head()
# Out:
#                    event_name  event_id           open_date score_name  \
# 23376   Oxford Utd v Man City  28887113 2018-09-25 18:45:00      0 - 3
# 23645    Liverpool v Man City  28906153 2018-10-07 15:30:00      0 - 0
# 21543  Southampton v Man City  28694904 2018-05-13 14:00:00      0 - 1
# 22715       Wolves v Man City  28845369 2018-08-25 11:30:00      1 - 1
# 21784      Arsenal v Man City  28766966 2018-08-12 15:00:00      0 - 2
#
#          home_team away_team     home_elo     away_elo  home_team_goal  \
# 23376   Oxford Utd  Man City   957.001975  1383.753316             0.0
# 23645    Liverpool  Man City  1276.415383  1391.785574             0.0
# 21543  Southampton  Man City  1122.527736  1386.532533             0.0
# 22715       Wolves  Man City  1120.931960  1414.104101             1.0
# 21784      Arsenal  Man City  1205.686049  1402.363592             0.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 23376             3.0         1.494509          1.395823         2.773566
# 23645             0.0         2.574000          0.739038         2.759821
# 21543             1.0         1.214888          0.967319         2.681761
# 22715             1.0         1.736459          0.838059         2.671427
# 21784             2.0         2.840681          0.704898         2.650448
#
#        away_defence_elo
# 23376          0.486744
# 23645          0.459993
# 21543          0.628548
# 22715          0.495721
# 21784          0.553545

# %%
df.sort_values(by='home_defence_elo', ascending=True).head()
# Out:
#                   event_name  event_id           open_date score_name  \
# 17654    Man Utd v Newcastle  28457655 2017-11-18 17:30:00      4 - 1
# 17417      Man Utd v Benfica  28439904 2017-10-31 19:45:00      2 - 0
# 15888       Man Utd v Burton  28360635 2017-09-20 19:00:00      4 - 1
# 18253  Man Utd v CSKA Moscow  28490325 2017-12-05 19:45:00      2 - 1
# 16063      Man Utd v Everton  28371686 2017-09-17 15:00:00      4 - 0
#
#       home_team    away_team     home_elo     away_elo  home_team_goal  \
# 17654   Man Utd    Newcastle  1278.142452  1111.019805             4.0
# 17417   Man Utd      Benfica  1287.412427   978.715539             2.0
# 15888   Man Utd       Burton  1271.630356  1032.793270             4.0
# 18253   Man Utd  CSKA Moscow  1280.217854   995.410091             2.0
# 16063   Man Utd      Everton  1261.050888  1138.504313             4.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 17654             1.0         2.078745          0.248318         1.273462
# 17417             0.0         2.096722          0.261455         1.187967
# 15888             1.0         1.906479          0.269287         0.933733
# 18253             1.0         2.180426          0.270558         1.163544
# 16063             0.0         1.773728          0.284694         1.279554
#
#        away_defence_elo
# 17654          0.998069
# 17417          1.530109
# 15888          1.418433
# 18253          1.392784
# 16063          1.031004

# %%
df.sort_values(by='home_defence_elo', ascending=False).head()
# Out:
#                       event_name  event_id           open_date  \
# 3837         Kilmarnock v Hearts  27637421 2016-01-02 15:00:00
# 4023   Kilmarnock v Inverness CT  27647791 2016-01-16 15:00:00
# 15388           E Stirling v Ayr  28340242 2017-08-16 18:45:00
# 9832          E Stirling v Annan  27989543 2016-10-29 14:00:00
# 4244       Kilmarnock v Hamilton  27663911 2016-01-30 15:00:00
#
#                score_name   home_team     away_team    home_elo     away_elo  \
# 3837                2 - 2  Kilmarnock        Hearts  928.619463  1063.298635
# 4023                2 - 1  Kilmarnock  Inverness CT  955.814043  1026.981717
# 15388  Any Other Away Win  E Stirling           Ayr  863.611049  1022.794363
# 9832                1 - 2  E Stirling         Annan  822.786374   951.916996
# 4244                0 - 1  Kilmarnock      Hamilton  954.519158   936.940786
#
#        home_team_goal  away_team_goal  home_attack_elo  home_defence_elo  \
# 3837              2.0             2.0         1.341127          1.965830
# 4023              2.0             1.0         1.383820          1.962949
# 15388             NaN             NaN         0.868180          1.912560
# 9832              1.0             2.0         0.861291          1.911525
# 4244              0.0             1.0         1.415446          1.905959
#
#        away_attack_elo  away_defence_elo
# 3837          1.237337          1.162005
# 4023          1.288653          1.343607
# 15388         1.266984          1.277990
# 9832          1.224057          1.361124
# 4244          1.174655          1.710177

# %%
df.sort_values(by='away_defence_elo', ascending=True).head()
# Out:
#                   event_name  event_id           open_date score_name  \
# 23645   Liverpool v Man City  28906153 2018-10-07 15:30:00      0 - 0
# 23376  Oxford Utd v Man City  28887113 2018-09-25 18:45:00      0 - 3
# 22715      Wolves v Man City  28845369 2018-08-25 11:30:00      1 - 1
# 23133     Cardiff v Man City  28875069 2018-09-22 14:00:00      0 - 5
# 21784     Arsenal v Man City  28766966 2018-08-12 15:00:00      0 - 2
#
#         home_team away_team     home_elo     away_elo  home_team_goal  \
# 23645   Liverpool  Man City  1276.415383  1391.785574             0.0
# 23376  Oxford Utd  Man City   957.001975  1383.753316             0.0
# 22715      Wolves  Man City  1120.931960  1414.104101             1.0
# 23133     Cardiff  Man City  1090.836106  1378.626547             0.0
# 21784     Arsenal  Man City  1205.686049  1402.363592             0.0
#
#        away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 23645             0.0         2.574000          0.739038         2.759821
# 23376             3.0         1.494509          1.395823         2.773566
# 22715             1.0         1.736459          0.838059         2.671427
# 23133             5.0         1.445318          0.928599         2.626734
# 21784             2.0         2.840681          0.704898         2.650448
#
#        away_defence_elo
# 23645          0.459993
# 23376          0.486744
# 22715          0.495721
# 23133          0.514066
# 21784          0.553545

# %%
df.loc[:, 'expected_home_goals'] = df.apply(lambda x: expected_result_score(x.home_attack_elo, x.away_defence_elo, HOME_TEAM_BASE), axis=1)
df.loc[:, 'expected_away_goals'] = df.apply(lambda x: expected_result_score(x.away_attack_elo, x.home_defence_elo, AWAY_TEAM_BASE), axis=1)
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  home_team_goal  away_team_goal  home_attack_elo  \
# 6     1000.0             1.0             3.0         1.359675
# 93    1000.0             NaN             NaN         1.359675
# 17    1000.0             5.0             0.0         1.359675
# 59    1000.0             1.0             2.0         1.359675
# 58    1000.0             4.0             2.0         1.359675
#
#     home_defence_elo  away_attack_elo  away_defence_elo  expected_home_goals  \
# 6           1.182145         1.182145          1.359675             1.359675
# 93          1.182145         1.182145          1.359675             1.359675
# 17          1.182145         1.182145          1.359675             1.359675
# 59          1.182145         1.182145          1.359675             1.359675
# 58          1.182145         1.182145          1.359675             1.359675
#
#     expected_away_goals
# 6              1.182145
# 93             1.182145
# 17             1.182145
# 59             1.182145
# 58             1.182145

# %%
def replace_score_name(val):
    try:
        home_score = int(val.split(' - ')[0])
        away_score = int(val.split(' - ')[1])
        if home_score <= 3 and away_score <= 3:
            return val
        elif home_score > away_score:
            return "Any Other Home Win"
        elif home_score == away_score:
            return "Any Other Draw"
        elif away_score > home_score:
            return "Any Other Away Win"
        else:
            return val
    except:
        return val
    
df.loc[:, 'modified_score_name'] = df.score_name.apply(lambda x: replace_score_name(x))
df.head()
# Out:
#                                     event_name  event_id           open_date  \
# 6                          Leicester v Chelsea  27425814 2015-04-29 18:45:00
# 93  Nostell Miners Welfare v Frickley Athletic  27434210 2015-05-01 18:30:00
# 17                             Celtic v Dundee  27428357 2015-05-01 18:45:00
# 59                      Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00
# 58                            Norwich v Fulham  27428774 2015-05-02 11:15:00
#
#             score_name               home_team          away_team  home_elo  \
# 6                1 - 3               Leicester            Chelsea    1000.0
# 93  Any Other Away Win  Nostell Miners Welfare  Frickley Athletic    1000.0
# 17               5 - 0                  Celtic             Dundee    1000.0
# 59               1 - 2            Nottm Forest            Cardiff    1000.0
# 58               4 - 2                 Norwich             Fulham    1000.0
#
#     away_elo  home_team_goal  away_team_goal  home_attack_elo  \
# 6     1000.0             1.0             3.0         1.359675
# 93    1000.0             NaN             NaN         1.359675
# 17    1000.0             5.0             0.0         1.359675
# 59    1000.0             1.0             2.0         1.359675
# 58    1000.0             4.0             2.0         1.359675
#
#     home_defence_elo  away_attack_elo  away_defence_elo  expected_home_goals  \
# 6           1.182145         1.182145          1.359675             1.359675
# 93          1.182145         1.182145          1.359675             1.359675
# 17          1.182145         1.182145          1.359675             1.359675
# 59          1.182145         1.182145          1.359675             1.359675
# 58          1.182145         1.182145          1.359675             1.359675
#
#     expected_away_goals modified_score_name
# 6              1.182145               1 - 3
# 93             1.182145  Any Other Away Win
# 17             1.182145  Any Other Home Win
# 59             1.182145               1 - 2
# 58             1.182145  Any Other Home Win

# %% [markdown]
# ## Building Models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

new_df = df[(df.home_team_goal >= 0) & (df.away_team_goal >= 0)]
X_train, X_test, y_train, y_test = train_test_split(new_df[[
    'home_elo', 'away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'
]].values,
    new_df.modified_score_name, test_size=0.15, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
t_y_train = le.fit_transform(y_train)
t_y_test = le.transform(y_test)

# %%
len(le.classes_)
# Out:
# 18

# %%
import xgboost

# %%
reg = xgboost.XGBClassifier(
    objective='multi:softprob',
    max_depth=2,
    n_estimators=50,
    booster='gbtree',
    colsample_bytree=0.8,
    subsample=0.6,
    num_class=len(le.classes_)
)

# %%
reg.fit(X_train, t_y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=50,
#        n_jobs=1, nthread=None, num_class=18, objective='multi:softprob',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=0.6)

# %%
preds = reg.predict_proba(X_test)
preds
# Out:
# array([[0.06419473, 0.07695021, 0.05408479, ..., 0.0186948 , 0.01353842,
#         0.0201679 ],
#        [0.05980239, 0.07483677, 0.04976902, ..., 0.0170463 , 0.00956826,
#         0.01217938],
#        [0.08463682, 0.08477417, 0.05002462, ..., 0.0114561 , 0.0112586 ,
#         0.01996825],
#        ...,
#        [0.10001373, 0.09048221, 0.06178163, ..., 0.01648529, 0.01065105,
#         0.01315318],
#        [0.06443883, 0.08085464, 0.05062741, ..., 0.01803866, 0.01283795,
#         0.02651127],
#        [0.06511039, 0.11879858, 0.08280075, ..., 0.01624031, 0.01152063,
#         0.01097828]], dtype=float32)

# %%
for preddle, entry in zip(preds[0], le.classes_):
    if preddle > 0.05:
        print("{0} - {1}".format(entry, 100.*preddle))
# Out:
# 0 - 0 - 6.4194731414318085
# 0 - 1 - 7.6950207352638245
# 0 - 2 - 5.408479273319244
# 1 - 0 - 7.695949077606201
# 1 - 1 - 12.270421534776688
# 1 - 2 - 9.374585747718811
# 2 - 0 - 6.864984333515167
# 2 - 1 - 8.932986110448837
# 2 - 2 - 6.618112325668335

# %% [markdown]
# ## Getting serious

# %%
new_df.head()
# Out:
#                 event_name  event_id           open_date score_name  \
# 6      Leicester v Chelsea  27425814 2015-04-29 18:45:00      1 - 3
# 17         Celtic v Dundee  27428357 2015-05-01 18:45:00      5 - 0
# 59  Nottm Forest v Cardiff  27428775 2015-05-02 11:15:00      1 - 2
# 58        Norwich v Fulham  27428774 2015-05-02 11:15:00      4 - 2
# 60     Watford v Sheff Wed  27428776 2015-05-02 11:15:00      1 - 1
#
#        home_team  away_team  home_elo  away_elo  home_team_goal  \
# 6      Leicester    Chelsea    1000.0    1000.0             1.0
# 17        Celtic     Dundee    1000.0    1000.0             5.0
# 59  Nottm Forest    Cardiff    1000.0    1000.0             1.0
# 58       Norwich     Fulham    1000.0    1000.0             4.0
# 60       Watford  Sheff Wed    1000.0    1000.0             1.0
#
#     away_team_goal  home_attack_elo  home_defence_elo  away_attack_elo  \
# 6              3.0         1.359675          1.182145         1.182145
# 17             0.0         1.359675          1.182145         1.182145
# 59             2.0         1.359675          1.182145         1.182145
# 58             2.0         1.359675          1.182145         1.182145
# 60             1.0         1.359675          1.182145         1.182145
#
#     away_defence_elo  expected_home_goals  expected_away_goals  \
# 6           1.359675             1.359675             1.182145
# 17          1.359675             1.359675             1.182145
# 59          1.359675             1.359675             1.182145
# 58          1.359675             1.359675             1.182145
# 60          1.359675             1.359675             1.182145
#
#    modified_score_name
# 6                1 - 3
# 17  Any Other Home Win
# 59               1 - 2
# 58  Any Other Home Win
# 60               1 - 1

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest

# %%
pipeline = Pipeline(
    [
#        ('scaler', StandardScaler(with_mean=True, with_std=True)),
#        ('poly', PolynomialFeatures()),
        ('gb', xgboost.XGBClassifier(objective='multi:softprob', eval_metric='mlogloss', num_class=len(le.classes_)))
    ]
)

parameters = {}
#parameters['scaler__with_mean'] = [True, False]
#parameters['scaler__with_std'] = [True, False]
#parameters['poly__degree'] = [2, 3]
#parameters['poly__iteraction_only'] = [True, False]
parameters['gb__max_depth'] = [2,3]
parameters['gb__n_estimators'] = [20, 50]
parameters['gb__subsample'] = [0.95]
#parameters['gb__colsample_by_tree'] = [0, 0.1]


CV = GridSearchCV(pipeline, parameters, cv=3, n_jobs=2)
CV.fit(X_train, t_y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('gb', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, eval_metric='mlogloss', gamma=0,
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, num_class=18, objective='multi:softprob',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))]),
#        fit_params=None, iid='warn', n_jobs=2,
#        param_grid={'gb__max_depth': [2, 3], 'gb__n_estimators': [20, 50], 'gb__subsample': [0.95]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
CV.best_score_
# Out:
# 0.12457912457912458

# %%
CV.best_params_
# Out:
# {'gb__max_depth': 2, 'gb__n_estimators': 20, 'gb__subsample': 0.95}

# %%
y_pred = CV.predict_proba(X_test)
y_pred
# Out:
# array([[0.0598127 , 0.07140359, 0.0541502 , ..., 0.02830382, 0.02534379,
#         0.02891737],
#        [0.06074722, 0.06924522, 0.05604382, ..., 0.03133948, 0.02393467,
#         0.025686  ],
#        [0.07751267, 0.07669456, 0.05405901, ..., 0.02402424, 0.02496634,
#         0.02848671],
#        ...,
#        [0.08526745, 0.08106828, 0.05932556, ..., 0.03174999, 0.02430498,
#         0.02608341],
#        [0.06139733, 0.07407317, 0.05319775, ..., 0.02868436, 0.02534775,
#         0.02975502],
#        [0.06110508, 0.09572478, 0.07282094, ..., 0.02767294, 0.02491836,
#         0.02607094]], dtype=float32)

# %% [markdown]
# ## Testing

# %%
conn = psycopg2.connect("dbname=football")
cur = conn.cursor()

sql = """
SELECT
    a.event_name,
    a.name,
    a.ltp AS lay_ltp,
    a.odds AS lay_odds,
    a.vol AS lay_vol,
    a.pct_chance AS lay_pct_chance,
    b.ltp AS back_ltp,
    b.odds AS back_odds,
    b.vol AS back_vol,
    b.pct_chance AS back_pct_chance
FROM
last_correct_score_lay_odds a
INNER JOIN
last_correct_score_back_odds b
ON a.event_name = b.event_name
AND a.mc_id = b.mc_id
AND a.open_date = b.open_date
AND a.rc_id = b.rc_id
"""

cur.execute(sql)

recent_odds = cur.fetchall()
recent_colnames = [desc[0] for desc in cur.description]
conn.close()

# %%
odds_df = pd.DataFrame(recent_odds, columns=recent_colnames)
odds_df.head()
# Out:
#   event_name   name lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp  \
# 0   18746827  0 - 0     0.0       60    9.66  1.6666666666666667      0.0
# 1   18746827  1 - 0     0.0       24   21.11  4.1666666666666667      0.0
# 2   18746827  1 - 1     0.0       17   26.53  5.8823529411764706      0.0
# 3   18746827  0 - 1     0.0       46    1.57  2.1739130434782609      0.0
# 4   18746827  2 - 0     0.0       18    10.2  5.5555555555555556      0.0
#
#   back_odds back_vol     back_pct_chance
# 0        30      6.9  3.3333333333333333
# 1      13.5       16  7.4074074074074074
# 2      12.5        4  8.0000000000000000
# 3        27     7.69  3.7037037037037037
# 4      12.5    21.38  8.0000000000000000

# %%
odds_df.columns = [
    'event_name',
    'score_name',
    'lay_ltp',
    'lay_odds',
    'lay_vol',
    'lay_pct_chance',
    'back_ltp',
    'back_odds',
    'back_vol',
    'back_pct_chance'
]

# %%
# Out:
# 6                  1 - 3
# 17    Any Other Home Win
# 59                 1 - 2
# 60                 1 - 1
# 23                 0 - 3
# 22                 2 - 2
# 21                 3 - 0
# 19                 1 - 0
# 52                 0 - 1
# 56                 0 - 0
# 51                 3 - 2
# 99                 2 - 0
# 40                 3 - 1
# 42                 2 - 3
# 44                 0 - 2
# 38                 2 - 1
# 32    Any Other Away Win
# 37                 3 - 3
# Name: modified_score_name, dtype: object

# %%
odds_df.tail()
# Out:
#               event_name          score_name lay_ltp lay_odds lay_vol  \
# 10473  Yeovil v Tranmere               2 - 3     0.0       42   29.49
# 10474  Yeovil v Tranmere               1 - 3     0.0       30   58.47
# 10475  Yeovil v Tranmere               0 - 3     0.0       42   42.62
# 10476  Yeovil v Tranmere  Any Other Home Win    26.0       28   59.15
# 10477  Yeovil v Tranmere  Any Other Away Win     0.0       26   11.46
#
#            lay_pct_chance back_ltp back_odds back_vol     back_pct_chance
# 10473  2.3809523809523810      0.0        38    14.24  2.6315789473684211
# 10474  3.3333333333333333      0.0        27    17.49  3.7037037037037037
# 10475  2.3809523809523810      0.0        36    23.99  2.7777777777777778
# 10476  3.5714285714285714     23.0        23     9.11  4.3478260869565217
# 10477  3.8461538461538462     22.0        22    26.05  4.5454545454545455

# %%
current = new_df[(new_df.open_date >= '2018-10-01') & (new_df.open_date < '2018-11-01')]
merged = current.merge(odds_df[odds_df.score_name != 'Any Other Draw'], how='inner', left_on='event_name', right_on='event_name')
merged = merged[[
    'event_name', 'score_name_x', 'modified_score_name', 'score_name_y', 'lay_ltp', 'lay_odds', 'lay_vol', 'lay_pct_chance', 'back_ltp', 'back_odds', 'back_vol', 'back_pct_chance',
    'home_elo', 'away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'    
]].drop_duplicates()
merged.head()
# Out:
#                      event_name score_name_x modified_score_name score_name_y  \
# 0  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        0 - 0
# 1  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 2  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
# 4  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 5  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
#
#   lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp back_odds back_vol  \
# 0     0.0       65    0.76  1.5384615384615385     12.0      12.5     5.02
# 1     0.0       24    0.76  4.1666666666666667      0.0       6.2     3.95
# 2     0.0       65    0.76  1.5384615384615385      0.0       8.2     3.95
# 4     0.0       24    0.76  4.1666666666666667      0.0       6.2     3.96
# 5     0.0       65    0.76  1.5384615384615385      0.0       8.2     3.96
#
#        back_pct_chance   home_elo    away_elo  home_attack_elo  \
# 0   8.0000000000000000  1093.4093  1054.92836           1.5883
# 1  16.1290322580645161  1093.4093  1054.92836           1.5883
# 2  12.1951219512195122  1093.4093  1054.92836           1.5883
# 4  16.1290322580645161  1093.4093  1054.92836           1.5883
# 5  12.1951219512195122  1093.4093  1054.92836           1.5883
#
#    home_defence_elo  away_attack_elo  away_defence_elo  expected_home_goals  \
# 0          0.991137         1.610078          1.327148             1.550304
# 1          0.991137         1.610078          1.327148             1.550304
# 2          0.991137         1.610078          1.327148             1.550304
# 4          0.991137         1.610078          1.327148             1.550304
# 5          0.991137         1.610078          1.327148             1.550304
#
#    expected_away_goals
# 0             1.349926
# 1             1.349926
# 2             1.349926
# 4             1.349926
# 5             1.349926

# %%
merged[merged.modified_score_name == 'Any Other Draw']
# Out:
# Empty DataFrame
# Columns: [event_name, score_name_x, modified_score_name, score_name_y, lay_ltp, lay_odds, lay_vol, lay_pct_chance, back_ltp, back_odds, back_vol, back_pct_chance, home_elo, away_elo, home_attack_elo, home_defence_elo, away_attack_elo, away_defence_elo, expected_home_goals, expected_away_goals]
# Index: []

# %%
all_predictions = CV.predict_proba(merged[[    
        'home_elo', 'away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals'
]].values)

le.classes_
# Out:
# array(['0 - 0', '0 - 1', '0 - 2', '0 - 3', '1 - 0', '1 - 1', '1 - 2',
#        '1 - 3', '2 - 0', '2 - 1', '2 - 2', '2 - 3', '3 - 0', '3 - 1',
#        '3 - 2', '3 - 3', 'Any Other Away Win', 'Any Other Home Win'],
#       dtype=object)

# %%
all_predictions[0]
# Out:
# array([0.06075007, 0.07128209, 0.04406761, 0.04357809, 0.078604  ,
#        0.1042027 , 0.07554507, 0.05196718, 0.06641594, 0.07928316,
#        0.06114903, 0.03321532, 0.05147579, 0.05280213, 0.04339551,
#        0.0280975 , 0.02530066, 0.02886816], dtype=float32)

# %%
merged.loc[:, 'back_prob'] = 0
for index, row in merged.iterrows():
    preds = CV.predict_proba(
        row[['home_elo', 'away_elo', 'home_attack_elo', 'home_defence_elo', 'away_attack_elo', 'away_defence_elo', 'expected_home_goals', 'expected_away_goals']].values.reshape(1, -1)
    )
    score_name = row.score_name_y
    score_index = le.transform([score_name])[0]
    this_pred = preds[0]
    merged.loc[index, 'back_prob'] = 100.*this_pred[score_index]

merged.head()
# Out:
#                      event_name score_name_x modified_score_name score_name_y  \
# 0  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        0 - 0
# 1  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 2  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
# 4  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        1 - 1
# 5  Leeds U23 v Nottm Forest U23        2 - 0               2 - 0        2 - 2
#
#   lay_ltp lay_odds lay_vol      lay_pct_chance back_ltp back_odds    ...      \
# 0     0.0       65    0.76  1.5384615384615385     12.0      12.5    ...
# 1     0.0       24    0.76  4.1666666666666667      0.0       6.2    ...
# 2     0.0       65    0.76  1.5384615384615385      0.0       8.2    ...
# 4     0.0       24    0.76  4.1666666666666667      0.0       6.2    ...
# 5     0.0       65    0.76  1.5384615384615385      0.0       8.2    ...
#
#        back_pct_chance   home_elo    away_elo  home_attack_elo  \
# 0   8.0000000000000000  1093.4093  1054.92836           1.5883
# 1  16.1290322580645161  1093.4093  1054.92836           1.5883
# 2  12.1951219512195122  1093.4093  1054.92836           1.5883
# 4  16.1290322580645161  1093.4093  1054.92836           1.5883
# 5  12.1951219512195122  1093.4093  1054.92836           1.5883
#
#    home_defence_elo  away_attack_elo  away_defence_elo  expected_home_goals  \
# 0          0.991137         1.610078          1.327148             1.550304
# 1          0.991137         1.610078          1.327148             1.550304
# 2          0.991137         1.610078          1.327148             1.550304
# 4          0.991137         1.610078          1.327148             1.550304
# 5          0.991137         1.610078          1.327148             1.550304
#
#    expected_away_goals  back_prob
# 0             1.349926   6.075007
# 1             1.349926  10.420270
# 2             1.349926   6.114903
# 4             1.349926  10.420270
# 5             1.349926   6.114903
#
# [5 rows x 21 columns]

# %%
import decimal
merged.loc[:, 'prob_diff'] = merged[['back_pct_chance', 'back_prob']].apply(lambda x: x.back_prob - float(x.back_pct_chance), axis=1)
merged.sort_values(by='prob_diff').head(10)
# Out:
#                                            event_name score_name_x  \
# 6599                    Linfield FC U20 v Ards FC U20        2 - 1
# 6526                Larkhall Athletic FC v Cinderford        2 - 3
# 4217                     Sheff Utd U23 v Barnsley U23        1 - 0
# 5627                           Stockport v Altrincham        2 - 0
# 8380                        Sheff Utd U23 v Crewe U23        1 - 2
# 1129                        Curzon Ashton v Southport        1 - 2
# 4225  Mansfield Town FC (Res) v Grimsby Town FC (Res)        1 - 0
# 8328                     Dundee (Res) v Partick (Res)        2 - 2
# 8310                             Leeds U23 v Hull U23        2 - 1
# 6743                     Leicester U23 v West Ham U23        3 - 0
#
#      modified_score_name        score_name_y lay_ltp lay_odds lay_vol  \
# 6599               2 - 1  Any Other Away Win    1.14     1000    0.01
# 6526               2 - 3  Any Other Away Win    1.14     1000    0.01
# 4217               1 - 0  Any Other Away Win    1.12     1000    0.01
# 5627               2 - 0  Any Other Away Win     0.0       42       4
# 8380               1 - 2  Any Other Away Win    1.14     1000    0.01
# 1129               1 - 2  Any Other Away Win     0.0       34       8
# 4225               1 - 0  Any Other Away Win    1.12     1000    2.55
# 8328               2 - 2  Any Other Away Win    1.14     1000    2.56
# 8310               2 - 1  Any Other Away Win    1.14     1000    2.56
# 6743               3 - 0  Any Other Away Win     0.0       34       4
#
#               lay_pct_chance back_ltp back_odds    ...         home_elo  \
# 6599  0.10000000000000000000     1.14      1.02    ...      1217.256543
# 6526  0.10000000000000000000     1.14      1.02    ...      1045.633007
# 4217  0.10000000000000000000     1.12      1.02    ...      1015.643170
# 5627      2.3809523809523810      0.0      1.02    ...      1043.005128
# 8380  0.10000000000000000000     1.14      1.02    ...      1008.141596
# 1129      2.9411764705882353      0.0      1.02    ...       948.078395
# 4225  0.10000000000000000000     1.12      1.02    ...      1050.157398
# 8328  0.10000000000000000000     1.14      1.02    ...       999.715461
# 8310  0.10000000000000000000     1.14      1.02    ...      1100.166194
# 6743      2.9411764705882353      0.0      1.02    ...      1099.437375
#
#          away_elo  home_attack_elo  home_defence_elo  away_attack_elo  \
# 6599   932.861070         1.734892          1.101166         1.143051
# 6526   909.332455         1.268795          1.047148         1.175954
# 4217   938.410081         1.370701          1.314074         1.099028
# 5627   949.801325         1.261487          1.018973         1.386877
# 8380   970.670005         1.332339          1.252990         1.037923
# 1129   889.742599         1.026830          1.384455         1.113521
# 4225   984.914752         1.450030          1.208580         1.038861
# 8328   971.126800         1.447580          1.297710         1.159019
# 8310  1004.010895         1.624887          0.983290         1.190829
# 6743  1028.629574         1.607023          0.927075         1.308925
#
#       away_defence_elo  expected_home_goals  expected_away_goals  back_prob  \
# 6599          1.409786             1.798831             1.064750   2.317144
# 6526          1.476203             1.377534             1.041663   2.348089
# 4217          1.753019             1.767234             1.221681   2.360647
# 5627          1.613762             1.497226             1.195446   2.364459
# 8380          1.531472             1.500682             1.100124   2.396144
# 1129          1.648200             1.244724             1.304086   2.400845
# 4225          1.326175             1.414304             1.062092   2.406252
# 8328          1.469460             1.564462             1.272323   2.423984
# 8310          1.182447             1.413090             0.990512   2.478511
# 6743          1.286380             1.520395             1.026500   2.501597
#
#       prob_diff
# 6599 -95.722072
# 6526 -95.691126
# 4217 -95.678569
# 5627 -95.674757
# 8380 -95.643072
# 1129 -95.638371
# 4225 -95.632964
# 8328 -95.615232
# 8310 -95.560705
# 6743 -95.537619
#
# [10 rows x 22 columns]

# %%
merged.sort_values(by='prob_diff', ascending=False).head(10)
# Out:
#                              event_name score_name_x modified_score_name  \
# 839               Tottenham v Barcelona        2 - 4  Any Other Away Win
# 848                  Chelsea v MOL Vidi        1 - 0               1 - 0
# 3744         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 3065                      Wales v Spain        1 - 4  Any Other Away Win
# 7839             Chesterfield v Wrexham        1 - 1               1 - 1
# 4181  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 3747         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 6486                 Man Utd v Juventus        0 - 1               0 - 1
# 2673             Guiseley v Cleethorpes        2 - 1               2 - 1
# 4254         Scotland U21 v England U21        0 - 2               0 - 2
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 839   Any Other Home Win    30.0       30   68.09      3.3333333333333333
# 848                1 - 0    14.0     15.5   56.39      6.4516129032258065
# 3744               1 - 1    24.0      140   62.44  0.71428571428571428571
# 3065               2 - 0    70.0       80    3.37      1.2500000000000000
# 7839               1 - 1     0.0      7.2   39.25     13.8888888888888889
# 4181               0 - 0    1.28     1.41  135.52     70.9219858156028369
# 3747               2 - 1    44.0     1000    0.87  0.10000000000000000000
# 6486  Any Other Home Win    40.0       42       5      2.3809523809523810
# 2673               0 - 1     0.0       70    5.79      1.4285714285714286
# 4254               2 - 0     0.0       60  129.13      1.6666666666666667
#
#      back_ltp back_odds    ...         home_elo     away_elo  home_attack_elo  \
# 839      29.0        27    ...      1298.170964  1002.081203         2.520367
# 848      14.5      14.5    ...      1296.821144  1000.000000         1.905816
# 3744     30.0        50    ...      1092.907627  1062.393582         1.324826
# 3065     70.0        70    ...      1039.321042  1025.859130         1.463129
# 7839      0.0       6.8    ...       900.739051  1168.371120         0.975305
# 4181     1.28      1000    ...      1034.896702   987.787993         1.474994
# 3747     44.0        95    ...      1092.907627  1062.393582         1.324826
# 6486     40.0        40    ...      1201.244857  1036.180366         1.961969
# 2673      0.0        28    ...       944.301215  1028.364873         1.110359
# 4254      0.0        50    ...      1013.733267  1151.219682         1.340988
#
#       home_defence_elo  away_attack_elo  away_defence_elo  \
# 839           0.785386         1.172790          1.478477
# 848           0.615530         1.182145          1.359675
# 3744          1.230296         1.205698          1.390246
# 3065          0.994992         1.293464          1.357001
# 7839          1.357706         1.016207          0.859640
# 4181          1.115403         1.303134          1.178748
# 3747          1.230296         1.205698          1.390246
# 6486          0.697516         1.289869          1.307055
# 2673          1.275006         1.184689          1.358283
# 4254          1.082352         1.182145          1.359675
#
#       expected_home_goals  expected_away_goals  back_prob  prob_diff
# 839              2.740584             0.779170  17.183170  13.479466
# 848              1.905816             0.615530  15.969659   9.073108
# 3744             1.354613             1.254808  10.200647   8.200647
# 3065             1.460251             1.088687   9.152086   7.723515
# 7839             0.616626             1.167124  22.177429   7.471547
# 4181             1.278722             1.229560   7.273190   7.173190
# 3747             1.354613             1.254808   7.536238   6.483607
# 6486             1.886040             0.761077   8.239257   5.739257
# 2673             1.109222             1.277749   9.220285   5.648856
# 4254             1.340988             1.082352   7.583500   5.583500
#
# [10 rows x 22 columns]

# %%
def calculate_return(row, stake=1):
    score_name = row.modified_score_name
    score_name_guess = row.score_name_y
    if score_name == score_name_guess:
        return stake * row.back_odds
    else:
        return -stake
        
    
merged.loc[:, 'bet_return'] = merged.apply(lambda x: calculate_return(x), axis=1)
merged.sort_values(by='bet_return', ascending=False).head(10)
# Out:
#                           event_name score_name_x modified_score_name  \
# 439    Newport County v Macclesfield        3 - 3               3 - 3
# 533            Aston Villa v Preston        3 - 3               3 - 3
# 1290               Swansea v Ipswich        2 - 3               2 - 3
# 1900          Queen of South v Alloa        3 - 3               3 - 3
# 4659          Doncaster v Gillingham        3 - 3               3 - 3
# 8853    Concord Rangers v Chelmsford        3 - 0               3 - 0
# 4424      Fulham U23 v West Brom U23        0 - 3               0 - 3
# 2628  Coalville Town v St Neots Town        3 - 3               3 - 3
# 2613              Plymouth v Swindon        0 - 3               0 - 3
# 7637      Fleetwood Town v Blackpool        3 - 2               3 - 2
#
#      score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance back_ltp  \
# 439         3 - 3   100.0      120   42.32  0.83333333333333333333    100.0
# 533         3 - 3   110.0      110    1.88  0.90909090909090909091    110.0
# 1290        2 - 3    95.0      110   36.07  0.90909090909090909091     95.0
# 1900        3 - 3     0.0      110    3.52  0.90909090909090909091      0.0
# 4659        3 - 3    90.0       85     2.5      1.1764705882352941     80.0
# 8853        3 - 0     0.0      140    8.58  0.71428571428571428571      0.0
# 4424        0 - 3     0.0      120    3.03  0.83333333333333333333      0.0
# 2628        3 - 3     0.0      120    3.65  0.83333333333333333333      0.0
# 2613        0 - 3     0.0       65   28.72      1.5384615384615385      0.0
# 7637        3 - 2    50.0       60     2.7      1.6666666666666667     50.0
#
#      back_odds     ...         away_elo home_attack_elo  home_defence_elo  \
# 439        100     ...       963.840599        1.381157          1.094293
# 533        100     ...      1045.660160        1.676784          1.155422
# 1290        95     ...       994.686548        1.267285          0.939467
# 1900        75     ...      1003.082428        1.221954          1.335217
# 4659        75     ...       954.938534        1.316563          0.998227
# 8853        60     ...      1097.160389        1.378631          0.897893
# 4424        55     ...       845.825970        1.469745          1.052950
# 2628        55     ...       932.581222        1.355695          1.136805
# 2613        55     ...      1007.355182        1.519172          1.165459
# 7637        50     ...      1080.582700        1.290141          1.170805
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 439          1.088558          1.401806             1.423954
# 533          1.390803          1.358432             1.675252
# 1290         1.038131          1.163579             1.084513
# 1900         1.242855          1.208485             1.086078
# 4659         1.274330          1.262142             1.222122
# 8853         1.255764          1.039675             1.054169
# 4424         0.880102          1.693672             1.830780
# 2628         0.943471          1.360492             1.356510
# 2613         1.315485          1.356825             1.515987
# 7637         1.027665          0.958577             0.909556
#
#       expected_away_goals  back_prob  prob_diff  bet_return
# 439              1.007661   2.377577   1.377577         100
# 533              1.359363   2.835740   1.835740         100
# 1290             0.825017   2.624154   1.571523          95
# 1900             1.403788   2.779088   1.445754          75
# 4659             1.076069   3.106835   1.773502          75
# 8853             0.953810   3.643792   1.977125          60
# 4424             0.783916   3.730118   1.911936          55
# 2628             0.907285   2.433120   0.614938          55
# 2613             1.296917   4.382453   2.564271          55
# 7637             1.017806   3.846113   1.846113          50
#
# [10 rows x 23 columns]

# %%
merged[merged.bet_return > 0].shape
# Out:
# (508, 23)

# %%
merged.sort_values(by='prob_diff').head(10)
# Out:
#                                            event_name score_name_x  \
# 6599                    Linfield FC U20 v Ards FC U20        2 - 1
# 6526                Larkhall Athletic FC v Cinderford        2 - 3
# 4217                     Sheff Utd U23 v Barnsley U23        1 - 0
# 5627                           Stockport v Altrincham        2 - 0
# 8380                        Sheff Utd U23 v Crewe U23        1 - 2
# 1129                        Curzon Ashton v Southport        1 - 2
# 4225  Mansfield Town FC (Res) v Grimsby Town FC (Res)        1 - 0
# 8328                     Dundee (Res) v Partick (Res)        2 - 2
# 8310                             Leeds U23 v Hull U23        2 - 1
# 6743                     Leicester U23 v West Ham U23        3 - 0
#
#      modified_score_name        score_name_y lay_ltp lay_odds lay_vol  \
# 6599               2 - 1  Any Other Away Win    1.14     1000    0.01
# 6526               2 - 3  Any Other Away Win    1.14     1000    0.01
# 4217               1 - 0  Any Other Away Win    1.12     1000    0.01
# 5627               2 - 0  Any Other Away Win     0.0       42       4
# 8380               1 - 2  Any Other Away Win    1.14     1000    0.01
# 1129               1 - 2  Any Other Away Win     0.0       34       8
# 4225               1 - 0  Any Other Away Win    1.12     1000    2.55
# 8328               2 - 2  Any Other Away Win    1.14     1000    2.56
# 8310               2 - 1  Any Other Away Win    1.14     1000    2.56
# 6743               3 - 0  Any Other Away Win     0.0       34       4
#
#               lay_pct_chance back_ltp back_odds     ...         away_elo  \
# 6599  0.10000000000000000000     1.14      1.02     ...       932.861070
# 6526  0.10000000000000000000     1.14      1.02     ...       909.332455
# 4217  0.10000000000000000000     1.12      1.02     ...       938.410081
# 5627      2.3809523809523810      0.0      1.02     ...       949.801325
# 8380  0.10000000000000000000     1.14      1.02     ...       970.670005
# 1129      2.9411764705882353      0.0      1.02     ...       889.742599
# 4225  0.10000000000000000000     1.12      1.02     ...       984.914752
# 8328  0.10000000000000000000     1.14      1.02     ...       971.126800
# 8310  0.10000000000000000000     1.14      1.02     ...      1004.010895
# 6743      2.9411764705882353      0.0      1.02     ...      1028.629574
#
#      home_attack_elo  home_defence_elo  away_attack_elo  away_defence_elo  \
# 6599        1.734892          1.101166         1.143051          1.409786
# 6526        1.268795          1.047148         1.175954          1.476203
# 4217        1.370701          1.314074         1.099028          1.753019
# 5627        1.261487          1.018973         1.386877          1.613762
# 8380        1.332339          1.252990         1.037923          1.531472
# 1129        1.026830          1.384455         1.113521          1.648200
# 4225        1.450030          1.208580         1.038861          1.326175
# 8328        1.447580          1.297710         1.159019          1.469460
# 8310        1.624887          0.983290         1.190829          1.182447
# 6743        1.607023          0.927075         1.308925          1.286380
#
#       expected_home_goals  expected_away_goals  back_prob  prob_diff  \
# 6599             1.798831             1.064750   2.317144 -95.722072
# 6526             1.377534             1.041663   2.348089 -95.691126
# 4217             1.767234             1.221681   2.360647 -95.678569
# 5627             1.497226             1.195446   2.364459 -95.674757
# 8380             1.500682             1.100124   2.396144 -95.643072
# 1129             1.244724             1.304086   2.400845 -95.638371
# 4225             1.414304             1.062092   2.406252 -95.632964
# 8328             1.564462             1.272323   2.423984 -95.615232
# 8310             1.413090             0.990512   2.478511 -95.560705
# 6743             1.520395             1.026500   2.501597 -95.537619
#
#       bet_return
# 6599          -1
# 6526          -1
# 4217          -1
# 5627          -1
# 8380          -1
# 1129          -1
# 4225          -1
# 8328          -1
# 8310          -1
# 6743          -1
#
# [10 rows x 23 columns]

# %%
merged[merged.prob_diff > 2].bet_return.sum()
# Out:
# Decimal('-237.7')

# %%
merged[merged.prob_diff < 2].bet_return.sum()
# Out:
# Decimal('-550.12')

# %%
merged.sort_values(by='prob_diff', ascending=False).head()
# Out:
#                       event_name score_name_x modified_score_name  \
# 839        Tottenham v Barcelona        2 - 4  Any Other Away Win
# 848           Chelsea v MOL Vidi        1 - 0               1 - 0
# 3744  Leyton Orient v Hartlepool        0 - 0               0 - 0
# 3065               Wales v Spain        1 - 4  Any Other Away Win
# 7839      Chesterfield v Wrexham        1 - 1               1 - 1
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 839   Any Other Home Win    30.0       30   68.09      3.3333333333333333
# 848                1 - 0    14.0     15.5   56.39      6.4516129032258065
# 3744               1 - 1    24.0      140   62.44  0.71428571428571428571
# 3065               2 - 0    70.0       80    3.37      1.2500000000000000
# 7839               1 - 1     0.0      7.2   39.25     13.8888888888888889
#
#      back_ltp back_odds     ...         away_elo home_attack_elo  \
# 839      29.0        27     ...      1002.081203        2.520367
# 848      14.5      14.5     ...      1000.000000        1.905816
# 3744     30.0        50     ...      1062.393582        1.324826
# 3065     70.0        70     ...      1025.859130        1.463129
# 7839      0.0       6.8     ...      1168.371120        0.975305
#
#       home_defence_elo  away_attack_elo  away_defence_elo  \
# 839           0.785386         1.172790          1.478477
# 848           0.615530         1.182145          1.359675
# 3744          1.230296         1.205698          1.390246
# 3065          0.994992         1.293464          1.357001
# 7839          1.357706         1.016207          0.859640
#
#       expected_home_goals  expected_away_goals  back_prob  prob_diff  \
# 839              2.740584             0.779170  17.183170  13.479466
# 848              1.905816             0.615530  15.969659   9.073108
# 3744             1.354613             1.254808  10.200647   8.200647
# 3065             1.460251             1.088687   9.152086   7.723515
# 7839             0.616626             1.167124  22.177429   7.471547
#
#       bet_return
# 839           -1
# 848         14.5
# 3744          -1
# 3065          -1
# 7839         6.8
#
# [5 rows x 23 columns]

# %%
merged.loc[:, 'pct_back_difference'] = merged.apply(lambda x: (float(x.back_prob) - float(x.back_pct_chance))/float(x.back_pct_chance), axis=1)
merged.sort_values(by='pct_back_difference').head()
# Out:
#                              event_name score_name_x modified_score_name  \
# 6599      Linfield FC U20 v Ards FC U20        2 - 1               2 - 1
# 6526  Larkhall Athletic FC v Cinderford        2 - 3               2 - 3
# 4217       Sheff Utd U23 v Barnsley U23        1 - 0               1 - 0
# 5627             Stockport v Altrincham        2 - 0               2 - 0
# 8380          Sheff Utd U23 v Crewe U23        1 - 2               1 - 2
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 6599  Any Other Away Win    1.14     1000    0.01  0.10000000000000000000
# 6526  Any Other Away Win    1.14     1000    0.01  0.10000000000000000000
# 4217  Any Other Away Win    1.12     1000    0.01  0.10000000000000000000
# 5627  Any Other Away Win     0.0       42       4      2.3809523809523810
# 8380  Any Other Away Win    1.14     1000    0.01  0.10000000000000000000
#
#      back_ltp back_odds         ...          home_attack_elo home_defence_elo  \
# 6599     1.14      1.02         ...                 1.734892         1.101166
# 6526     1.14      1.02         ...                 1.268795         1.047148
# 4217     1.12      1.02         ...                 1.370701         1.314074
# 5627      0.0      1.02         ...                 1.261487         1.018973
# 8380     1.14      1.02         ...                 1.332339         1.252990
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 6599         1.143051          1.409786             1.798831
# 6526         1.175954          1.476203             1.377534
# 4217         1.099028          1.753019             1.767234
# 5627         1.386877          1.613762             1.497226
# 8380         1.037923          1.531472             1.500682
#
#       expected_away_goals  back_prob  prob_diff  bet_return  \
# 6599             1.064750   2.317144 -95.722072          -1
# 6526             1.041663   2.348089 -95.691126          -1
# 4217             1.221681   2.360647 -95.678569          -1
# 5627             1.195446   2.364459 -95.674757          -1
# 8380             1.100124   2.396144 -95.643072          -1
#
#       pct_back_difference
# 6599            -0.976365
# 6526            -0.976049
# 4217            -0.975921
# 5627            -0.975883
# 8380            -0.975559
#
# [5 rows x 24 columns]

# %%
merged.sort_values(by='pct_back_difference', ascending=False).head()
# Out:
#                              event_name score_name_x modified_score_name  \
# 4181  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 7460                Liverpool v Cardiff        4 - 1  Any Other Home Win
# 5337                 Man City v Burnley        5 - 0  Any Other Home Win
# 6652          Liverpool v Crvena Zvezda        4 - 0  Any Other Home Win
# 6650          Liverpool v Crvena Zvezda        4 - 0  Any Other Home Win
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 4181               0 - 0    1.28     1.41  135.52     70.9219858156028369
# 7460               0 - 3  1000.0     1000    1.96  0.10000000000000000000
# 5337               0 - 3  1000.0     1000    5.93  0.10000000000000000000
# 6652  Any Other Away Win  1000.0      980    1.13  0.10204081632653061224
# 6650               1 - 3   670.0     1000    2.03  0.10000000000000000000
#
#      back_ltp back_odds         ...          home_attack_elo home_defence_elo  \
# 4181     1.28      1000         ...                 1.474994         1.115403
# 7460   1000.0      1000         ...                 2.613849         0.621046
# 5337   1000.0      1000         ...                 2.776272         0.765882
# 6652   1000.0      1000         ...                 2.530459         0.652771
# 6650    890.0       880         ...                 2.530459         0.652771
#
#       away_attack_elo  away_defence_elo  expected_home_goals  \
# 4181         1.303134          1.178748             1.278722
# 7460         1.268377          1.033042             1.985927
# 5337         1.412129          1.412610             2.884358
# 6652         1.149051          1.253148             2.332204
# 6650         1.149051          1.253148             2.332204
#
#       expected_away_goals  back_prob  prob_diff  bet_return  \
# 4181             1.229560   7.273190   7.173190          -1
# 7460             0.666348   2.749320   2.649320          -1
# 5337             0.914882   2.721364   2.621364          -1
# 6652             0.634496   2.170919   2.070919          -1
# 6650             0.634496   2.454126   2.340490          -1
#
#       pct_back_difference
# 4181            71.731905
# 7460            26.493201
# 5337            26.213642
# 6652            20.709185
# 6650            20.596309
#
# [5 rows x 24 columns]

# %%
merged[merged.pct_back_difference > 0].bet_return.sum()
# Out:
# Decimal('-269.8')

# %%
merged[merged.pct_back_difference < 0].bet_return.sum()
# Out:
# Decimal('-518.02')

# %%
merged[merged.pct_back_difference < 1].bet_return.sum()
# Out:
# Decimal('-598.32')

# %%
merged[merged.prob_diff > 0].bet_return.sum() / merged[merged.prob_diff > 0].shape[0]
# Out:
# Decimal('-0.06120689655172413793103448276')

# %%
merged[merged.prob_diff > 1].bet_return.sum() / merged[merged.prob_diff > 1].shape[0]
# Out:
# Decimal('-0.07593256814921090387374461980')

# %%
t = np.linspace(-5, 5, 100)

# %%
def pct_returns(val, frame):
    return frame[frame.prob_diff > val].bet_return.sum() / frame[frame.prob_diff > val].shape[0]

def other_pct_returns(val, frame):
    return frame[frame.pct_back_difference > val].bet_return.sum() / frame[frame.pct_back_difference > val].shape[0]

return_strategy = [100.*float(pct_returns(l, merged)) for l in t]
return_strategy[0]
# Out:
# -4.737957837710518

# %%
fig, ax = plt.subplots(figsize=(20,12))
plt.plot(t, return_strategy)
ax.axhline(y=0, color='k', ls=':')
plt.xlabel('Percentage edge', fontsize=18)
plt.xticks(fontsize=18)
plt.ylabel('Percentage returns', fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
merged.pct_back_difference.describe()
# Out:
# count    9056.000000
# mean        0.278749
# std         1.396142
# min        -0.976365
# 25%        -0.224314
# 50%        -0.015195
# 75%         0.417734
# max        71.731905
# Name: pct_back_difference, dtype: float64

# %%
t = np.linspace(-1, 1, 100)
return_strategy = [100.*float(other_pct_returns(l, merged)) for l in t]

# %%
fig, ax = plt.subplots(figsize=(20,12))
plt.plot(t, return_strategy)
ax.axhline(y=0, color='k', ls=':')
plt.xlabel('Percentage edge', fontsize=18)
plt.xticks(fontsize=18)
plt.ylabel('Percentage returns', fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
merged.loc[:, 'lay_prob_diff'] = merged.apply(lambda x: x.back_prob - float(x.lay_pct_chance), axis=1)
merged.sort_values(by='lay_prob_diff').head()
# Out:
#                              event_name score_name_x modified_score_name  \
# 96                  Hendon v Lancing FC        1 - 1               1 - 1
# 10         Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 4184  Nottm Forest U23 v Birmingham U23        0 - 1               0 - 1
# 3742         Leyton Orient v Hartlepool        0 - 0               0 - 0
# 1026           Crusaders v Cliftonville        2 - 2               2 - 2
#
#      score_name_y lay_ltp lay_odds lay_vol       lay_pct_chance back_ltp  \
# 96          0 - 0    1.03     1.03    3.03  97.0873786407766990     1.03
# 10          2 - 0    1.13     1.08       3  92.5925925925925926     1.13
# 4184        0 - 1    1.11     1.09    3.07  91.7431192660550459     1.11
# 3742        0 - 0    1.26     1.11   41.81  90.0900900900900901     1.26
# 1026        2 - 2     1.2      1.2    5.94  83.3333333333333333      1.2
#
#      back_odds      ...       home_defence_elo away_attack_elo  \
# 96          24      ...               1.187936        1.182145
# 10        1.02      ...               0.991137        1.610078
# 4184      1.03      ...               1.115403        1.303134
# 3742      1.02      ...               1.230296        1.205698
# 1026      1.02      ...               1.100760        1.418916
#
#       away_defence_elo  expected_home_goals  expected_away_goals  back_prob  \
# 96            1.359675             1.722344             1.187936   6.057049
# 10            1.327148             1.550304             1.349926   6.641594
# 4184          1.178748             1.278722             1.229560   6.572922
# 3742          1.390246             1.354613             1.254808   6.187685
# 1026          1.183364             1.643300             1.321230   5.993542
#
#       prob_diff  bet_return  pct_back_difference  lay_prob_diff
# 96     1.890382          -1             0.453692     -91.030330
# 10   -91.397621        1.02            -0.932256     -85.950998
# 4184 -90.514456        1.03            -0.932299     -85.170197
# 3742 -91.851531        1.02            -0.936886     -83.902405
# 1026 -92.045674        1.02            -0.938866     -77.339792
#
# [5 rows x 25 columns]

# %%
merged.sort_values(by='lay_prob_diff', ascending=False).head()
# Out:
#                          event_name score_name_x modified_score_name  \
# 839           Tottenham v Barcelona        2 - 4  Any Other Away Win
# 74          Burnley U23 v Crewe U23        3 - 2               3 - 2
# 848              Chelsea v MOL Vidi        1 - 0               1 - 0
# 3744     Leyton Orient v Hartlepool        0 - 0               0 - 0
# 8454  Millwall U23 v Colchester U23        2 - 3               2 - 3
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 839   Any Other Home Win    30.0       30   68.09      3.3333333333333333
# 74                 1 - 1     0.0      650       2  0.15384615384615384615
# 848                1 - 0    14.0     15.5   56.39      6.4516129032258065
# 3744               1 - 1    24.0      140   62.44  0.71428571428571428571
# 8454               1 - 1     0.0      200    3.92  0.50000000000000000000
#
#      back_ltp back_odds      ...       home_defence_elo away_attack_elo  \
# 839      29.0        27      ...               0.785386        1.172790
# 74        0.0       6.2      ...               1.252371        1.045378
# 848      14.5      14.5      ...               0.615530        1.182145
# 3744     30.0        50      ...               1.230296        1.205698
# 8454      0.0       8.6      ...               0.943744        0.977884
#
#       away_defence_elo  expected_home_goals  expected_away_goals  back_prob  \
# 839           1.478477             2.740584             0.779170  17.183170
# 74            1.485576             1.582174             1.107479   9.880914
# 848           1.359675             1.905816             0.615530  15.969659
# 3744          1.390246             1.354613             1.254808  10.200647
# 8454          1.688381             1.784971             0.780676   9.547978
#
#       prob_diff  bet_return  pct_back_difference  lay_prob_diff
# 839   13.479466          -1             3.639456      13.849836
# 74    -6.248118          -1            -0.387383       9.727068
# 848    9.073108        14.5             1.315601       9.518046
# 3744   8.200647          -1             4.100323       9.486361
# 8454  -2.079929          -1            -0.178874       9.047978
#
# [5 rows x 25 columns]

# %%
def calculate_return_lay(row, stake=1):
    score_name = row.modified_score_name
    score_name_guess = row.score_name_y
    if score_name == score_name_guess:
        return -stake * row.lay_odds
    else:
        return stake

# %%
merged.loc[:, 'lay_return'] = merged.apply(lambda x: calculate_return_lay(x), axis=1)
merged.sort_values(by='lay_return', ascending=False).head(10)
# Out:
#                         event_name score_name_x modified_score_name  \
# 0     Leeds U23 v Nottm Forest U23        2 - 0               2 - 0
# 6102            MK Dons v Notts Co        2 - 1               2 - 1
# 6096           Oldham v Cheltenham        2 - 0               2 - 0
# 6097           Oldham v Cheltenham        2 - 0               2 - 0
# 6098           Oldham v Cheltenham        2 - 0               2 - 0
# 6099           Oldham v Cheltenham        2 - 0               2 - 0
# 6100            MK Dons v Notts Co        2 - 1               2 - 1
# 6101            MK Dons v Notts Co        2 - 1               2 - 1
# 6103            MK Dons v Notts Co        2 - 1               2 - 1
# 6076      Wrexham v Harrogate Town        2 - 0               2 - 0
#
#             score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance  \
# 0                  0 - 0     0.0       65    0.76      1.5384615384615385
# 6102               1 - 1     9.8       10   89.96     10.0000000000000000
# 6096               1 - 3     0.0       75   70.45      1.3333333333333333
# 6097               0 - 3     0.0      120   10.78  0.83333333333333333333
# 6098  Any Other Home Win    15.5     15.5   15.04      6.4516129032258065
# 6099  Any Other Away Win     0.0      690   80.22  0.14492753623188405797
# 6100               0 - 0    19.0       19   42.37      5.2631578947368421
# 6101               1 - 0     9.6      9.8      19     10.2040816326530612
# 6103               0 - 1     0.0       24   28.08      4.1666666666666667
# 6076               3 - 3     0.0      180    2.62  0.55555555555555555556
#
#      back_ltp back_odds     ...     away_attack_elo away_defence_elo  \
# 0        12.0      12.5     ...            1.610078         1.327148
# 6102      9.8       9.4     ...            1.178821         1.622874
# 6096      0.0        60     ...            1.159660         1.587526
# 6097      0.0        95     ...            1.159660         1.587526
# 6098     15.5        14     ...            1.159660         1.587526
# 6099      0.0        65     ...            1.159660         1.587526
# 6100     17.5      17.5     ...            1.178821         1.622874
# 6101      9.6       9.4     ...            1.178821         1.622874
# 6103      0.0        21     ...            1.178821         1.622874
# 6076      0.0        75     ...            1.435068         1.176991
#
#       expected_home_goals  expected_away_goals  back_prob  prob_diff  \
# 0                1.550304             1.349926   6.075007  -1.924993
# 6102             1.422015             0.956539   9.631117  -1.007181
# 6096             1.353769             1.499372   4.626902   2.960235
# 6097             1.353769             1.499372   4.379251   3.326619
# 6098             1.353769             1.499372   2.562682  -4.580175
# 6099             1.353769             1.499372   2.947573   1.409112
# 6100             1.422015             0.956539   6.302299   0.588014
# 6101             1.422015             0.956539  10.913500   0.275202
# 6103             1.422015             0.956539   6.851125   2.089220
# 6076             1.161104             0.927511   2.376061   1.042728
#
#       bet_return  pct_back_difference  lay_prob_diff  lay_return
# 0             -1            -0.240624       4.536545           1
# 6102          -1            -0.094675      -0.368883           1
# 6096          -1             1.776141       3.293568           1
# 6097          -1             3.160288       3.545918           1
# 6098          -1            -0.641225      -3.888931           1
# 6099          -1             0.915923       2.802646           1
# 6100          -1             0.102902       1.039141           1
# 6101          -1             0.025869       0.709419           1
# 6103          -1             0.438736       2.684458           1
# 6076          -1             0.782046       1.820505           1
#
# [10 rows x 26 columns]

# %%
merged.sort_values(by='lay_return', ascending=True).head(10)
# Out:
#                           event_name score_name_x modified_score_name  \
# 8853    Concord Rangers v Chelmsford        3 - 0               3 - 0
# 7980         Hartlepool v Sutton Utd        2 - 3               2 - 3
# 2628  Coalville Town v St Neots Town        3 - 3               3 - 3
# 439    Newport County v Macclesfield        3 - 3               3 - 3
# 4424      Fulham U23 v West Brom U23        0 - 3               0 - 3
# 1900          Queen of South v Alloa        3 - 3               3 - 3
# 1290               Swansea v Ipswich        2 - 3               2 - 3
# 533            Aston Villa v Preston        3 - 3               3 - 3
# 5841      Charlton U23 v Ipswich U23        2 - 2               2 - 2
# 4659          Doncaster v Gillingham        3 - 3               3 - 3
#
#      score_name_y lay_ltp lay_odds lay_vol          lay_pct_chance back_ltp  \
# 8853        3 - 0     0.0      140    8.58  0.71428571428571428571      0.0
# 7980        2 - 3     0.0      130    0.39  0.76923076923076923077      0.0
# 2628        3 - 3     0.0      120    3.65  0.83333333333333333333      0.0
# 439         3 - 3   100.0      120   42.32  0.83333333333333333333    100.0
# 4424        0 - 3     0.0      120    3.03  0.83333333333333333333      0.0
# 1900        3 - 3     0.0      110    3.52  0.90909090909090909091      0.0
# 1290        2 - 3    95.0      110   36.07  0.90909090909090909091     95.0
# 533         3 - 3   110.0      110    1.88  0.90909090909090909091    110.0
# 5841        2 - 2     0.0       90    3.82      1.1111111111111111      0.0
# 4659        3 - 3    90.0       85     2.5      1.1764705882352941     80.0
#
#      back_odds     ...     away_attack_elo away_defence_elo  \
# 8853        60     ...            1.255764         1.039675
# 7980        32     ...            1.224036         1.104546
# 2628        55     ...            0.943471         1.360492
# 439        100     ...            1.088558         1.401806
# 4424        55     ...            0.880102         1.693672
# 1900        75     ...            1.242855         1.208485
# 1290        95     ...            1.038131         1.163579
# 533        100     ...            1.390803         1.358432
# 5841       8.8     ...            1.279599         1.264736
# 4659        75     ...            1.274330         1.262142
#
#       expected_home_goals  expected_away_goals  back_prob  prob_diff  \
# 8853             1.054169             0.953810   3.643792   1.977125
# 7980             0.832765             1.115745   3.674278   0.549278
# 2628             1.356510             0.907285   2.433120   0.614938
# 439              1.423954             1.007661   2.377577   1.377577
# 4424             1.830780             0.783916   3.730118   1.911936
# 1900             1.086078             1.403788   2.779088   1.445754
# 1290             1.084513             0.825017   2.624154   1.571523
# 533              1.675252             1.359363   2.835740   1.835740
# 5841             1.383846             0.958775   5.997449  -5.366188
# 4659             1.222122             1.076069   3.106835   1.773502
#
#       bet_return  pct_back_difference  lay_prob_diff  lay_return
# 8853          60             1.186275       2.929506        -140
# 7980          32             0.175769       2.905047        -130
# 2628          55             0.338216       1.599787        -120
# 439          100             1.377577       1.544244        -120
# 4424          55             1.051565       2.896785        -120
# 1900          75             1.084316       1.869997        -110
# 1290          95             1.492947       1.715063        -110
# 533          100             1.835740       1.926649        -110
# 5841         8.8            -0.472225       4.886338         -90
# 4659          75             1.330127       1.930365         -85
#
# [10 rows x 26 columns]

# %%
merged.bet_return.sum()
# Out:
# Decimal('-787.82')

# %%
merged.lay_return.sum()
# Out:
# Decimal('-1288.34')

# %%
merged[merged.lay_prob_diff > 2].lay_return.sum()
# Out:
# Decimal('-749.7')

# %%
merged[merged.lay_prob_diff < -2].lay_return.sum()
# Out:
# Decimal('167.96')

# %%
merged.lay_prob_diff.describe()
# Out:
# count    9056.000000
# mean        0.443483
# std         3.620688
# min       -91.030330
# 25%        -0.643256
# 50%         0.971020
# 75%         2.024838
# max        13.849836
# Name: lay_prob_diff, dtype: float64

# %%
def lay_pct_returns(val, frame):
    return frame[frame.lay_prob_diff < val].lay_return.sum() / frame[frame.prob_diff < val].shape[0]

t = np.linspace(-5, 5, 200)
return_strategy = [100.*float(pct_returns(l, merged)) for l in t]
return_strategy[0]
# Out:
# -4.737957837710518

# %%
fig, ax = plt.subplots(figsize=(20,12))
plt.plot(t, return_strategy)
ax.axhline(y=0, color='k', ls=':')
plt.xlabel('Percentage edge', fontsize=18)
plt.xticks(fontsize=18)
plt.ylabel('Percentage returns', fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
merged[merged.lay_prob_diff < -2].lay_return.sum()
# Out:
# Decimal('167.96')

# %%
merged[merged.lay_prob_diff < -2][['event_name', 'modified_score_name', 'score_name_y', 'back_odds', 'lay_odds', 'back_prob', 'lay_prob_diff', 'lay_return', 'bet_return']].sort_values(by='lay_prob_diff')
# Out:
#                              event_name modified_score_name  \
# 96                  Hendon v Lancing FC               1 - 1
# 10         Leeds U23 v Nottm Forest U23               2 - 0
# 4184  Nottm Forest U23 v Birmingham U23               0 - 1
# 3742         Leyton Orient v Hartlepool               0 - 0
# 1026           Crusaders v Cliftonville               2 - 2
# 948            Crusaders v Cliftonville               3 - 2
# 1031           Crusaders v Cliftonville               2 - 2
# 953            Crusaders v Cliftonville               3 - 2
# 4181  Nottm Forest U23 v Birmingham U23               0 - 1
# 3085          England U21 v Andorra U21  Any Other Home Win
# 862                  Chelsea v MOL Vidi               1 - 0
# 5338                 Man City v Burnley  Any Other Home Win
# 3387              Linfield v Newry City               3 - 1
# 7461                Liverpool v Cardiff  Any Other Home Win
# 6651          Liverpool v Crvena Zvezda  Any Other Home Win
# 3341                 Ross Co v Montrose               3 - 1
# 6506  Liverpool U19 v Crvena Zvezda U19               2 - 1
# 6687             Chelsea v BATE Borisov               3 - 1
# 7          Leeds U23 v Nottm Forest U23               2 - 0
# 5140                    Ards v Linfield               2 - 1
# 3019          Blackpool v West Brom U21               1 - 2
# 461                 Barnsley v Plymouth               1 - 1
# 9235                Arsenal v Blackpool               2 - 1
# 9216                    Chelsea v Derby               3 - 2
# 6874           Newtown v The New Saints               1 - 1
# 4458       Man Utd U23 v Sunderland U23               3 - 0
# 2906        Peterborough v Brighton U21               2 - 2
# 2300                   Fulham v Arsenal  Any Other Away Win
# 3722           Salford City v Braintree               2 - 2
# 8431    West Brom U23 v Aston Villa U23               1 - 1
# ...                                 ...                 ...
# 5930              Bury v Newport County               1 - 1
# 6875                 Brechin v Montrose               1 - 3
# 8461            Tranmere v Man City U21               0 - 1
# 7954                  Sheff Utd v Wigan  Any Other Home Win
# 1081                  Leeds v Brentford               1 - 1
# 1222             Stevenage v Colchester               3 - 1
# 1221             Stevenage v Colchester               3 - 1
# 5451       Dunfermline v Queen of South               0 - 1
# 2048                   Bury v Mansfield               2 - 2
# 3442               Rochdale v Doncaster               2 - 3
# 7499             Birmingham v Sheff Wed               3 - 1
# 6339               Birmingham v Reading               2 - 1
# 3777         Altrincham v Alfreton Town               3 - 1
# 8156                 C Palace v Arsenal               2 - 2
# 6264                    QPR v Sheff Wed               3 - 0
# 102               Everton v Southampton               1 - 1
# 5159               Newcastle v Brighton               0 - 1
# 8173                  Burnley v Chelsea  Any Other Away Win
# 7319             Cheltenham v Stevenage               0 - 2
# 238              Cheltenham v Morecambe               2 - 2
# 5810                 Everton v C Palace               2 - 0
# 7609              West Brom v Blackburn               1 - 1
# 5302          Dundee Utd v Inverness CT               1 - 1
# 593            AFC Wimbledon v Bradford               0 - 1
# 150            Fleetwood Town v Wycombe               1 - 1
# 5991               Grimsby v Colchester               1 - 0
# 5489               West Ham v Tottenham               0 - 1
# 3013          Blackpool v West Brom U21               1 - 2
# 1316                        QPR v Derby               1 - 1
# 3906                   Exeter v Swindon               2 - 0
#
#             score_name_y back_odds lay_odds  back_prob  lay_prob_diff  \
# 96                 0 - 0        24     1.03   6.057049     -91.030330
# 10                 2 - 0      1.02     1.08   6.641594     -85.950998
# 4184               0 - 1      1.03     1.09   6.572922     -85.170197
# 3742               0 - 0      1.02     1.11   6.187685     -83.902405
# 1026               2 - 2      1.02      1.2   5.993542     -77.339792
# 948                2 - 2      1.02      1.2   6.069853     -77.263481
# 1031               3 - 2      1.02     1.37   4.345636     -68.647065
# 953                3 - 2      1.02     1.37   4.532943     -68.459758
# 4181               0 - 0      1000     1.41   7.273190     -63.648795
# 3085  Any Other Home Win       1.5     1.55   9.550901     -54.965228
# 862   Any Other Home Win       2.2     2.24   7.931363     -36.711494
# 5338  Any Other Home Win      2.06     2.12  17.481066     -29.688745
# 3387  Any Other Home Win      3.25     3.55   3.358881     -24.810133
# 7461  Any Other Home Win      2.54     2.56  14.811879     -24.250621
# 6651  Any Other Home Win      2.22     2.26  20.782530     -23.465257
# 3341  Any Other Home Win      3.35     3.85   2.779488     -23.194538
# 6506  Any Other Home Win      1.68     3.85   2.848001     -23.126025
# 6687  Any Other Home Win       3.1      3.2   9.612150     -21.637850
# 7                  1 - 0      1.02      3.5   7.860400     -20.711029
# 5140  Any Other Away Win      3.95      4.4   3.514808     -19.212465
# 3019  Any Other Home Win       4.2      4.3   4.320000     -18.935813
# 461   Any Other Home Win       4.4      4.7   2.562934     -18.713662
# 9235  Any Other Home Win      2.72     2.84  16.891684     -18.319584
# 9216  Any Other Home Win       4.4      4.5   4.629013     -17.593209
# 6874  Any Other Away Win       2.9      4.6   4.569742     -17.169388
# 4458  Any Other Home Win       4.7      5.2   2.536188     -16.694581
# 2906  Any Other Home Win       3.9      4.8   4.348199     -16.485134
# 2300  Any Other Away Win         5      5.2   3.124656     -16.106114
# 3722  Any Other Home Win       4.7      4.9   4.846052     -15.562111
# 8431  Any Other Away Win       5.1      5.6   2.371726     -15.485416
# ...                  ...       ...      ...        ...            ...
# 5930               3 - 1        16     16.5   4.020802      -2.039804
# 6875               0 - 0        12     12.5   5.960474      -2.039526
# 8461               0 - 1        10       11   7.051422      -2.039487
# 7954               2 - 1         9      9.4   8.599279      -2.039019
# 1081               1 - 1         8      8.2  10.160193      -2.034929
# 1222  Any Other Away Win        21       22   2.513256      -2.032199
# 1221  Any Other Away Win        21       22   2.513256      -2.032199
# 5451               1 - 1       7.8      8.2  10.163262      -2.031859
# 2048               1 - 0       9.8     10.5   7.492628      -2.031182
# 3442  Any Other Away Win        20       22   2.514641      -2.030813
# 7499               0 - 0      10.5     11.5   6.665085      -2.030568
# 6339               1 - 1         8      8.4   9.878058      -2.026704
# 3777  Any Other Away Win        16       19   3.237712      -2.025446
# 8156               0 - 2        12     12.5   5.975076      -2.024924
# 6264               1 - 0       9.2      9.6   8.393934      -2.022732
# 102                2 - 1       9.4      9.6   8.395304      -2.021363
# 5159               0 - 0       8.4      8.8   9.343517      -2.020120
# 8173               1 - 2       9.8     10.5   7.504281      -2.019528
# 7319               0 - 0        11       12   6.315223      -2.018110
# 238   Any Other Home Win        21       22   2.528814      -2.016640
# 5810               2 - 1       9.6      9.8   8.188388      -2.015693
# 7609               1 - 0       9.8     10.5   7.509583      -2.014226
# 5302  Any Other Home Win      15.5       17   3.870038      -2.012315
# 593                0 - 0      11.5     12.5   5.988977      -2.011023
# 150                0 - 0      11.5     12.5   5.991389      -2.008611
# 5991  Any Other Away Win      19.5       22   2.538176      -2.007279
# 5489               1 - 2       9.8       10   7.993235      -2.006765
# 3013               3 - 1        12       13   5.687042      -2.005266
# 1316               0 - 1        10     10.5   7.521339      -2.002471
# 3906               2 - 1        10     10.5   7.523376      -2.000433
#
#      lay_return bet_return
# 96            1         -1
# 10        -1.08       1.02
# 4184      -1.09       1.03
# 3742      -1.11       1.02
# 1026       -1.2       1.02
# 948           1         -1
# 1031          1         -1
# 953       -1.37       1.02
# 4181          1         -1
# 3085      -1.55        1.5
# 862           1         -1
# 5338      -2.12       2.06
# 3387          1         -1
# 7461      -2.56       2.54
# 6651      -2.26       2.22
# 3341          1         -1
# 6506          1         -1
# 6687          1         -1
# 7             1         -1
# 5140          1         -1
# 3019          1         -1
# 461           1         -1
# 9235          1         -1
# 9216          1         -1
# 6874          1         -1
# 4458          1         -1
# 2906          1         -1
# 2300       -5.2          5
# 3722          1         -1
# 8431          1         -1
# ...         ...        ...
# 5930          1         -1
# 6875          1         -1
# 8461        -11         10
# 7954          1         -1
# 1081       -8.2          8
# 1222          1         -1
# 1221          1         -1
# 5451          1         -1
# 2048          1         -1
# 3442          1         -1
# 7499          1         -1
# 6339          1         -1
# 3777          1         -1
# 8156          1         -1
# 6264          1         -1
# 102           1         -1
# 5159          1         -1
# 8173          1         -1
# 7319          1         -1
# 238           1         -1
# 5810          1         -1
# 7609          1         -1
# 5302          1         -1
# 593           1         -1
# 150           1         -1
# 5991          1         -1
# 5489          1         -1
# 3013          1         -1
# 1316          1         -1
# 3906          1         -1
#
# [1129 rows x 9 columns]
